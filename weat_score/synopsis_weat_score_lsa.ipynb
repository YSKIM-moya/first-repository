# %% [markdown]
# # 임베딩 내 편향성 알아보기

# %%
import os
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
import numpy as np
from numpy import dot
from numpy.linalg import norm

# %%
def cos_sim(i, j):
    return dot(i, j.T)/(norm(i)*norm(j))

# s(w,A,B)는 개별 단어 w가 개념축 A-B에 대해 가지는 편향성을 계산한 값
# -2 ~ 2의 값
def s(w, A, B):
    c_a = cos_sim(w, A)
    c_b = cos_sim(w, B)
    mean_A = np.mean(c_a, axis=-1)
    mean_B = np.mean(c_b, axis=-1)
    return mean_A - mean_B #, c_a, c_b

# s(X,A,B)평균 - s(Y,A,B)평균을 전체 표준편차로 나눈 값
def weat_score(X, Y, A, B):
    
    s_X = s(X, A, B)
    s_Y = s(Y, A, B)

    mean_X = np.mean(s_X)
    mean_Y = np.mean(s_Y)
    
    std_dev = np.std(np.concatenate([s_X, s_Y], axis=0))
    
    return  (mean_X-mean_Y)/std_dev

# %%
from gensim.models import Word2Vec

def get_representative_words(token_list, vector_size=100, window=5, min_count=3, sg=0, topn=15):
    """
    Word2Vec을 학습하고 중심 벡터에 가장 가까운 단어 topn개를 반환합니다.
    
    Args:
        token_list (List[List[str]]): 문장 단위 토큰 리스트
        vector_size (int): 임베딩 차원 수
        window (int): 윈도우 크기
        min_count (int): 최소 단어 등장 빈도
        sg (int): 0=CBOW, 1=Skip-gram
        topn (int): 반환할 대표 단어 수
        
    Returns:
        List[str]: 중심 벡터에 가장 가까운 대표 단어 리스트
    """
    
    # Word2Vec 모델 학습
    model = Word2Vec(sentences=token_list, vector_size=vector_size, window=window, min_count=min_count, sg=sg)
    
    print('상위 15개 단어:', model.wv.index_to_key[:15])

    # 중심 벡터 계산
    vector_mean = np.mean([model.wv[word] for word in model.wv.index_to_key], axis=0)

    # 중심 벡터에 가장 가까운 단어 topn개 추출
    representative_words = model.wv.similar_by_vector(vector_mean, topn=topn)
    
    return [word for word, _ in representative_words]

# %% [markdown]
# ## 1. 명사만 추출 및 embedding model 만들기

# %%
from konlpy.tag import Okt

okt = Okt()

# %%
#  형태소 분석기를 이용하여 품사가 명사인 경우, 해당 단어를 추출하기


def read_token(file_name):
    result = []
    with open(os.getenv('HOME')+'/aiffel/weat/'+file_name, 'r') as fread: 
        print(file_name, '파일을 읽고 있습니다.')
        while True:
            line = fread.readline() 
            if not line: break 
           
            tokenlist = okt.pos(line, stem=True, norm=True) # 어간 추출, 표준화
            res = []
            for word in tokenlist:
                if word[1] in ["Noun"]:      #, "Adjective", "Verb"]:
                    res.append(word[0]) # 명사일 때만 tokenized 에 저장하게 됩니다. 
            result.append(res)  
    
    print(len(result))        
    return result

def read_token_to_str(file_name):
    tokens = read_token(file_name)
    return ' '.join(tokens)

# %% [markdown]
# ### 전체 파일 ###

# %%
# 약 15분정도 걸립니다.

tokenized = []
with open(os.getenv('HOME')+'/aiffel/weat/synopsis.txt', 'r') as file:
    while True:
        line = file.readline()
        if not line: break
        words = okt.pos(line, stem=True, norm=True) # 어간 추출, 표준화
        # [('오늘', 'Noun'), ('은', 'Josa'), ('날씨', 'Noun'), ('가', 'Josa'), ('정말', 'Adverb'), ('좋다', 'Adjective'), ('!', 'Punctuation')]
        
        res = []
        for w in words:
            if w[1] in ["Noun"]:      # "Adjective", "Verb" 등을 포함할 수도 있습니다.
                res.append(w[0])    # 명사일 때만 tokenized 에 저장하게 됩니다. 
        tokenized.append(res)

print(len(tokenized))
# Out:
# 71156

# %%
# 전체 문서 파일에 대해서 word embedding 만들기

from gensim.models import Word2Vec

# 1. 토큰 추출하기
all_txt = 'synopsis.txt'
# tokenized = read_token(all_txt)        
print(f'{all_txt}의 토큰: ', len(tokenized))

# 2. 토큰으로 embedding model 만들기
model_all = Word2Vec(tokenized, vector_size=100, window=5, min_count=3, sg=0)
# Out:
# synopsis.txt의 토큰:  71156

# %%
print('Word2Vec 단어 수:', len(model_all.wv))
print('상위 20개 단어:', model_all.wv.index_to_key[:20])
# Out:
# Word2Vec 단어 수: 24320
# 상위 20개 단어: ['그', '것', '이', '자신', '그녀', '수', '영화제', '제', '위해', '시작', '사람', '날', '국제', '사랑', '영화', '친구', '집', '남자', '알', '속']

# %%
model_all.wv.most_similar(positive=['사랑'])
# Out:
# [('진심', 0.7075039148330688),
#  ('연애관', 0.7037286162376404),
#  ('행복', 0.7025247812271118),
#  ('애정', 0.7010518312454224),
#  ('첫사랑', 0.7007163166999817),
#  ('감정', 0.6770108938217163),
#  ('존경심', 0.6744487881660461),
#  ('종이학', 0.6735074520111084),
#  ('이별', 0.6652079820632935),
#  ('연애', 0.6640956997871399)]

# %%
model_all.wv.most_similar(positive=['영화'])
# Out:
# [('작품', 0.8931462168693542),
#  ('다큐멘터리', 0.8572531342506409),
#  ('드라마', 0.8158106803894043),
#  ('영화로', 0.7954885959625244),
#  ('코미디', 0.79298996925354),
#  ('형식', 0.7834155559539795),
#  ('주제', 0.7798845767974854),
#  ('행위예술', 0.7741764187812805),
#  ('소재', 0.7681736350059509),
#  ('감동', 0.7668689489364624)]

# %% [markdown]
# ### target 파일 (art, gen) ###

# %%
art_txt = 'synopsis_art.txt'
gen_txt = 'synopsis_gen.txt'

# 2개의 파일을 처리하는데 10분 가량 걸립니다. 
# 여기서 읽어들인 토큰들은 "중심벡터유사도방식" 사용할 예정임. 
art_tokens = read_token(art_txt) # 리스트 형태로 반환
gen_tokens = read_token(gen_txt)
art_str = ' '.join(art_tokens)   # 리스트를 문자열로 변환
gen_str = ' '.join(gen_tokens)

print(f'{art_txt}의 토큰: ', len(art_tokens))
print(f'{gen_txt}의 토큰: ', len(gen_tokens))
# Out:
# synopsis_art.txt 파일을 읽고 있습니다.
# synopsis_gen.txt 파일을 읽고 있습니다.
# synopsis_art.txt의 토큰:  208471
# synopsis_gen.txt의 토큰:  1008358

# %% [markdown]
# ### 모든 장르 파일 ###

# %%
#4. 모든 장르의 대표 단어를 추출 
genre_txt = ['synopsis_SF.txt', 'synopsis_family.txt', 'synopsis_show.txt', 'synopsis_horror.txt', 'synopsis_etc.txt', 
             'synopsis_documentary.txt', 'synopsis_drama.txt', 'synopsis_romance.txt', 'synopsis_musical.txt', 
             'synopsis_mystery.txt', 'synopsis_crime.txt', 'synopsis_historical.txt', 'synopsis_western.txt', 
             'synopsis_adult.txt', 'synopsis_thriller.txt', 'synopsis_animation.txt', 'synopsis_action.txt', 
             'synopsis_adventure.txt', 'synopsis_war.txt', 'synopsis_comedy.txt', 'synopsis_fantasy.txt']
genre_name = ['SF', '가족', '공연', '공포(호러)', '기타', '다큐멘터리', '드라마', '멜로로맨스', '뮤지컬', '미스터리', '범죄', '사극', '서부극(웨스턴)',
         '성인물(에로)', '스릴러', '애니메이션', '액션', '어드벤처', '전쟁', '코미디', '판타지']


# 1). 토큰 추출하기
genre_tokens_dict = {}
genre_all_str = []

for file_name, name in zip(genre_txt, genre_name):
    tokens = read_token(file_name)
    
    rep_words = get_representative_words(tokens)  # 중심단어 추출
    genre_tokens_dict[name] = {
        'tokens': tokens,
        'representative_words': rep_words
    }
      
    genre_all_str.append(' '.join(tokens))
    

    
# 2) 결과 확인
for genre, data in genre_tokens_dict.items():
    print(f'{genre} 장르의 토큰 수:', len(data['tokens']))
    print(f'  대표 단어: {data["representative_words"][:15]}')  # 일부만 출력

print('\n전체 통합 토큰 수:', len(genre_all_str))
# Out:
# synopsis_SF.txt 파일을 읽고 있습니다.
# synopsis_family.txt 파일을 읽고 있습니다.
# synopsis_show.txt 파일을 읽고 있습니다.
# synopsis_horror.txt 파일을 읽고 있습니다.
# synopsis_etc.txt 파일을 읽고 있습니다.
# synopsis_documentary.txt 파일을 읽고 있습니다.
# synopsis_drama.txt 파일을 읽고 있습니다.
# synopsis_romance.txt 파일을 읽고 있습니다.
# synopsis_musical.txt 파일을 읽고 있습니다.
# synopsis_mystery.txt 파일을 읽고 있습니다.
# synopsis_crime.txt 파일을 읽고 있습니다.
# synopsis_historical.txt 파일을 읽고 있습니다.
# synopsis_western.txt 파일을 읽고 있습니다.
# synopsis_adult.txt 파일을 읽고 있습니다.
# synopsis_thriller.txt 파일을 읽고 있습니다.
# synopsis_animation.txt 파일을 읽고 있습니다.
# synopsis_action.txt 파일을 읽고 있습니다.
# synopsis_adventure.txt 파일을 읽고 있습니다.
# synopsis_war.txt 파일을 읽고 있습니다.
# synopsis_comedy.txt 파일을 읽고 있습니다.
# synopsis_fantasy.txt 파일을 읽고 있습니다.
# SF 장르의 토큰 수: 21712
#   대표 단어: ['티', '오', '코', '디', '수', '라', '트', '만', '드', '턴', '브', '블', '분', '저', '에']
# 가족 장르의 토큰 수: 8006
#   대표 단어: ['스', '리', '이', '기', '마', '가', '트', '로', '자', '드', '사', '모', '인', '지', '아']
# 공연 장르의 토큰 수: 7984
#   대표 단어: ['스', '리', '르', '이', '마', '로', '아', '트', '레', '피', '지', '인', '라', '가', '드']
# 공포(호러) 장르의 토큰 수: 57802
#   대표 단어: ['칙', '글', '채', '뉴', '셔', '엔', '딩', '삭', '잔', '뜨', '궁', '풋', '겨', '롱', '쇼']
# 기타 장르의 토큰 수: 49025
#   대표 단어: ['컨', '텐', '닥', '새', '멜', '흐', '돌', '며', '느', '싸', '힘', '온', '픽', '콩', '칭']
# 다큐멘터리 장르의 토큰 수: 156822
#   대표 단어: ['밈', '끈', '갬', '깜', '빡', '틈', '솜', '잎', '엉', '잭', '못', '쳐', '꺼', '낌', '텃']
# 드라마 장르의 토큰 수: 377566
#   대표 단어: ['껀', '퀘', '훨', '짹', '펭', '욜', '쥔', '쭉', '펄', '꿋', '쪼', '쫄', '빼', '뿍', '컥']
# 멜로로맨스 장르의 토큰 수: 102083
#   대표 단어: ['쟈', '삐', '룡', '샬', '던', '딜', '쿤', '홧', '룬', '팡', '똘', '툰', '훌', '쭉', '힐']
# 뮤지컬 장르의 토큰 수: 3442
#   대표 단어: ['이', '로', '리', '스', '메', '르', '니', '아', '프', '모', '지', '마', '인', '발', '전']
# 미스터리 장르의 토큰 수: 15726
#   대표 단어: ['오', '드', '스', '로', '니', '가', '트', '이', '어', '수', '리', '라', '거', '유', '레']
# 범죄 장르의 토큰 수: 29567
#   대표 단어: ['저', '류', '양', '슨', '허', '워', '느', '린', '애', '더', '면', '태', '급', '말', '송']
# 사극 장르의 토큰 수: 3620
#   대표 단어: ['기', '전', '성', '이', '일', '도', '아', '명', '군', '트', '나', '각', '라', '정', '화']
# 서부극(웨스턴) 장르의 토큰 수: 925
#   대표 단어: ['나', '금', '결', '보', '탠', '소', '치', '때', '최', '이', '식', '타', '발', '착', '라']
# 성인물(에로) 장르의 토큰 수: 45227
#   대표 단어: ['션', '괴', '볼', '돌', '힘', '농', '탈', '열', '슬', '색', '클', '양', '링', '헤', '철']
# 스릴러 장르의 토큰 수: 43043
#   대표 단어: ['허', '류', '며', '킨', '느', '런', '슨', '혈', '월', '싱', '홍', '캠', '젤', '급', '슈']
# 애니메이션 장르의 토큰 수: 121876
#   대표 단어: ['몇', '땡', '싹', '퐁', '흰', '텀', '빼', '꽁', '퀸', '훌', '뿜', '꼼', '빡', '뜻', '낌']
# 액션 장르의 토큰 수: 115561
#   대표 단어: ['끈', '쿵', '낌', '깜', '솜', '팽', '팬', '앗', '텀', '쌍', '둥', '캡', '륜', '못', '롱']
# 어드벤처 장르의 토큰 수: 9687
#   대표 단어: ['스', '리', '이', '르', '지', '어', '레', '드', '아', '사', '로', '라', '트', '마', '자']
# 전쟁 장르의 토큰 수: 8462
#   대표 단어: ['스', '리', '르', '레', '가', '드', '아', '지', '소', '트', '니', '대', '전', '마', '인']
# 코미디 장르의 토큰 수: 107432
#   대표 단어: ['팽', '똘', '톡', '꽁', '낌', '멧', '쭉', '뚱', '땅', '쳐', '몇', '띠', '캡', '샅', '쩍']
# 판타지 장르의 토큰 수: 11994
#   대표 단어: ['스', '드', '이', '리', '트', '라', '지', '아', '가', '로', '어', '인', '사', '고', '대']
#
# 전체 통합 토큰 수: 21

# %% [markdown]
# ## 2. TF-IDF를 이용한 단어셋 추출 방법

# %%
# 3. TF-IDF로 해당 데이터를 가장 잘 표현하는 단어 셋 만들기
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform([art_str, gen_str])

print(X.shape)

m1 = X[0].tocoo()   # art를 TF-IDF로 표현한 sparse matrix를 가져옵니다. 
m2 = X[1].tocoo()   # gen을 TF-IDF로 표현한 sparse matrix를 가져옵니다. 

w1 = [[i, j] for i, j in zip(m1.col, m1.data)]
w2 = [[i, j] for i, j in zip(m2.col, m2.data)]

w1.sort(key=lambda x: x[1], reverse=True)   #art를 구성하는 단어들을 TF-IDF가 높은 순으로 정렬합니다. 
w2.sort(key=lambda x: x[1], reverse=True)   #gen을 구성하는 단어들을 TF-IDF가 높은 순으로 정렬합니다.

#상위 100개의 단어들 중 중복되는 단어를 제외하고 상위 n(=15)개의 단어를 추출
n = 15
w1_, w2_ = [], []
for i in range(100):
    w1_.append(vectorizer.get_feature_names()[w1[i][0]])
    w2_.append(vectorizer.get_feature_names()[w2[i][0]])

print(w1_)
print(w2_)
    
# w1에만 있고 w2에는 없는, 예술영화를 잘 대표하는 단어를 15개 추출한다.
target_art, target_gen = [], []
for i in range(100):
    if (w1_[i] not in w2_) and (w1_[i] in model_all.wv): target_art.append(w1_[i])
    if len(target_art) == n: break 

# w2에만 있고 w1에는 없는, 일반영화를 잘 대표하는 단어를 15개 추출한다.
for i in range(100):
    if (w2_[i] not in w1_) and (w2_[i] in model_all.wv): target_gen.append(w2_[i])
    if len(target_gen) == n: break

print('target_art :', target_art)
print('target_get :', target_gen)
# Out:
# (2, 41082)
# /opt/conda/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# ['그녀', '자신', '시작', '위해', '사랑', '사람', '영화', '친구', '남자', '가족', '이야기', '마을', '사건', '마음', '세상', '아버지', '아이', '엄마', '모든', '여자', '대한', '서로', '과연', '다시', '시간', '아들', '소녀', '아내', '다른', '사이', '영화제', '세계', '사실', '하나', '점점', '남편', '감독', '여행', '인생', '발견', '모두', '순간', '우리', '가장', '마지막', '생활', '아빠', '모습', '통해', '죽음', '기억', '비밀', '학교', '음악', '한편', '소년', '생각', '도시', '명의', '사고', '결혼', '전쟁', '때문', '위기', '이제', '최고', '이자', '과거', '일상', '경찰', '상황', '간다', '미국', '결심', '운명', '현실', '관계', '지금', '단편', '여인', '하루', '이름', '이후', '준비', '인간', '감정', '만난', '국제', '처음', '충격', '살인', '누구', '동안', '존재', '그린', '어머니', '연인', '계속', '동생', '작품']
# ['자신', '그녀', '영화제', '위해', '사람', '시작', '국제', '영화', '친구', '사랑', '남자', '이야기', '대한', '서울', '여자', '사건', '남편', '아이', '가족', '아버지', '다른', '마을', '시간', '엄마', '아들', '모든', '단편', '마음', '사실', '다시', '세계', '모습', '작품', '통해', '생각', '서로', '세상', '발견', '감독', '아내', '관계', '소녀', '사이', '하나', '우리', '애니메이션', '때문', '여성', '죽음', '과연', '점점', '인간', '생활', '한편', '결혼', '상황', '모두', '기억', '명의', '소년', '여행', '가장', '간다', '순간', '이제', '도시', '비밀', '학교', '과거', '가지', '이자', '경찰', '마지막', '미국', '동안', '전쟁', '주인공', '대해', '존재', '현실', '연출', '사고', '살인', '일상', '어머니', '계속', '사회', '인생', '다큐멘터리', '부문', '섹스', '최고', '바로', '동생', '의도', '하루', '위기', '계획', '정체', '한국']
# target_art : ['아빠', '음악', '결심', '운명', '지금', '여인', '이름', '이후', '준비', '감정', '만난', '처음', '충격', '누구', '그린']
# target_get : ['서울', '애니메이션', '여성', '가지', '주인공', '대해', '연출', '사회', '다큐멘터리', '부문', '섹스', '바로', '의도', '계획', '정체']

# %%
# 2). TF-IDF로 해당 데이터를 가장 잘 표현하는 단어 셋 만들기
vectorizer_g = TfidfVectorizer()
X_g = vectorizer_g.fit_transform(genre_all_str)

print(X_g.shape)


m = [X_g[i].tocoo() for i in range(X_g.shape[0])] # TF-IDF로 표현한 sparse matrix list를 가져옵니다

w = [[[i, j] for i, j in zip(mm.col, mm.data)] for mm in m]


for i in range(len(w)):
    w[i].sort(key=lambda x: x[1], reverse=True) #단어들을 TF-IDF가 높은 순으로 정렬합니다.
    
    
attributes = []
for i in range(len(w)):
    print(genre_name[i], end=': ')
    attr = []
    j = 0
    while (len(attr) < 15):
        if vectorizer_g.get_feature_names()[w[i][j][0]] in model_all.wv:
            attr.append(vectorizer_g.get_feature_names()[w[i][j][0]])
        j += 1
    print( attr)
    attributes.append(attr)
    print()

# <-- 장르마다 중복된 단어 있음
# Out:
# (21, 42191)
# SF: ['위해', '자신', '지구', '시작', '사람', '인류', '인간', '미래', '우주', '그녀', '로봇', '세계', '모든', '박사', '우주선']
#
# 가족: ['엄마', '아빠', '가족', '영화제', '자신', '위해', '친구', '아주르', '아버지', '시작', '그녀', '아들', '마을', '국제', '낙타']
#
# 공연: ['오페라', '사랑', '토스카', '실황', '올레', '자신', '카바', '그녀', '공연', '오텔로', '리골레토', '백작', '프레', '베르디', '위해']
#
# 공포(호러): ['시작', '위해', '사람', '자신', '친구', '그녀', '사건', '공포', '발견', '죽음', '마을', '가족', '악령', '남자', '좀비']
#
# 기타: ['영화제', '국제', '서울', '단편', '영화', '자신', '사람', '이야기', '그녀', '남자', '위해', '시작', '사랑', '뉴미디어', '페스티벌']
#
# 다큐멘터리: ['영화제', '영화', '다큐', '국제', '다큐멘터리', '사람', '이야기', '대한', '자신', '감독', '위해', '서울', '우리', '시작', '세계']
#
# 드라마: ['자신', '영화제', '그녀', '사람', '사랑', '영화', '위해', '시작', '국제', '남자', '친구', '이야기', '엄마', '여자', '아버지']
#
# 멜로로맨스: ['그녀', '사랑', '자신', '시작', '남편', '남자', '여자', '사람', '친구', '섹스', '위해', '마음', '결혼', '서로', '아내']
#
# 뮤지컬: ['뮤지컬', '사랑', '에스메랄다', '그녀', '음악', '충무로', '모차르트', '영화', '토스카', '자신', '니웨', '카바', '영화제', '바흐', '페뷔스']
#
# 미스터리: ['사건', '그녀', '시작', '자신', '위해', '사람', '발견', '사고', '진실', '죽음', '기억', '살인', '친구', '아내', '남자']
#
# 범죄: ['사건', '위해', '자신', '경찰', '시작', '그녀', '범죄', '조직', '살인', '사람', '마약', '형사', '남자', '모든', '살해']
#
# 사극: ['조선', '위해', '시작', '신기전', '사랑', '자신', '아가멤논', '황제', '그녀', '루안', '최고', '운명', '사람', '하선', '전쟁']
#
# 서부극(웨스턴): ['서부', '보안관', '위해', '벌린', '카우보이', '그레이프바인', '헨리', '마을', '자신', '개릿', '아이', '시작', '무법자', '프린트', '마적']
#
# 성인물(에로): ['그녀', '남편', '마사지', '자신', '섹스', '관계', '영화', '정사', '남자', '위해', '시작', '여자', '유부녀', '마음', '사랑']
#
# 스릴러: ['자신', '그녀', '사건', '시작', '위해', '사람', '살인', '남자', '발견', '아내', '경찰', '친구', '모든', '사실', '살해']
#
# 애니메이션: ['애니메이션', '국제', '영화제', '친구', '인디애니페스트', '위해', '자신', '시작', '사람', '페스티벌', '서울', '이야기', '아이', '마을', '소녀']
#
# 액션: ['위해', '자신', '시작', '조직', '사건', '사람', '그녀', '경찰', '전쟁', '모든', '목숨', '사실', '친구', '가족', '요원']
#
# 어드벤처: ['위해', '자신', '시작', '친구', '마을', '아버지', '영화', '아이', '사람', '여행', '세계', '앤트', '세상', '가족', '모험']
#
# 전쟁: ['전쟁', '독일군', '전투', '위해', '작전', '시작', '부대', '윈터스', '독일', '연합군', '미군', '임무', '자신', '사람', '나치']
#
# 코미디: ['그녀', '자신', '시작', '위해', '사랑', '사람', '친구', '영화', '남자', '여자', '영화제', '가족', '과연', '마을', '사건']
#
# 판타지: ['자신', '그녀', '시작', '위해', '사람', '사랑', '요괴', '영화제', '이야기', '영화', '소녀', '남자', '인간', '세상', '마을']

# %%
def compute_weat_matrix(genre_names, attribute_sets, target_art, target_gen, model, verbose=True):
    """
    장르 쌍 간 WEAT 점수를 계산하는 행렬을 반환합니다.
    
    Args:
        genre_names (List[str]): 장르 이름 리스트
        attribute_sets (Dict[str, List[str]]): 각 장르에 대한 속성 단어 리스트
        target_art (List[str]): 예술영화 대표 단어 리스트
        target_gen (List[str]): 일반영화 대표 단어 리스트
        model (gensim Word2Vec): 학습된 Word2Vec 모델
        weat_score_fn (function): WEAT 점수를 계산하는 함수
        verbose (bool): True일 경우 결과를 출력

    Returns:
        matrix (2D List[float]): 장르 쌍 간 WEAT 점수 행렬 (대각선 위 삼각형만 사용)
    """

    n = len(genre_names)
    matrix = [[0 for _ in range(n)] for _ in range(n)]

    # X, Y는 고정된 target (예술, 일반 영화)
    X = np.array([model.wv[word] for word in target_art if word in model.wv])
    Y = np.array([model.wv[word] for word in target_gen if word in model.wv])

    for i in range(n - 1):
        for j in range(i + 1, n):
            #A_words = [w for w in attribute_sets[genre_names[i]] if w in model.wv]
            #B_words = [w for w in attribute_sets[genre_names[j]] if w in model.wv]

           # if not A_words or not B_words:
           #     matrix[i][j] = None  # 단어가 없으면 계산 불가
           #     continue

           # A = np.array([model.wv[word] for word in A_words])
            #B = np.array([model.wv[word] for word in B_words])
            A = np.array([model_all.wv[word] for word in attributes[i]])
            B = np.array([model_all.wv[word] for word in attributes[j]])
            
            score = weat_score(X, Y, A, B)
            matrix[i][j] = score

            if verbose:
                print(f"예술영화 vs 상업영화 | {genre_names[i]} vs {genre_names[j]}: WEAT score = {score:.4f}")

    return matrix

# %%
matrix_tfidf = compute_weat_matrix(
    genre_names=genre_name,
    #attribute_sets={g: genre_tokens_dict[g]['representative_words'] for g in genre_name},
    attribute_sets=attributes, # TF-IDF로 추출한 단어들
    target_art=target_art,
    target_gen=target_gen,
    model=model_all
)
# Out:
# 예술영화 vs 상업영화 | SF vs 가족: WEAT score = -0.5165
# 예술영화 vs 상업영화 | SF vs 공연: WEAT score = -0.3520
# 예술영화 vs 상업영화 | SF vs 공포(호러): WEAT score = -0.6551
# 예술영화 vs 상업영화 | SF vs 기타: WEAT score = 0.3432
# 예술영화 vs 상업영화 | SF vs 다큐멘터리: WEAT score = 0.5831
# 예술영화 vs 상업영화 | SF vs 드라마: WEAT score = -0.3625
# 예술영화 vs 상업영화 | SF vs 멜로로맨스: WEAT score = -0.7675
# 예술영화 vs 상업영화 | SF vs 뮤지컬: WEAT score = 0.3468
# 예술영화 vs 상업영화 | SF vs 미스터리: WEAT score = -0.6637
# 예술영화 vs 상업영화 | SF vs 범죄: WEAT score = -0.1905
# 예술영화 vs 상업영화 | SF vs 사극: WEAT score = -0.8164
# 예술영화 vs 상업영화 | SF vs 서부극(웨스턴): WEAT score = -0.4452
# 예술영화 vs 상업영화 | SF vs 성인물(에로): WEAT score = -0.5366
# 예술영화 vs 상업영화 | SF vs 스릴러: WEAT score = -0.4939
# 예술영화 vs 상업영화 | SF vs 애니메이션: WEAT score = 0.3529
# 예술영화 vs 상업영화 | SF vs 액션: WEAT score = -0.4409
# 예술영화 vs 상업영화 | SF vs 어드벤처: WEAT score = -0.7838
# 예술영화 vs 상업영화 | SF vs 전쟁: WEAT score = 0.1753
# 예술영화 vs 상업영화 | SF vs 코미디: WEAT score = -0.4299
# 예술영화 vs 상업영화 | SF vs 판타지: WEAT score = -0.1867
# 예술영화 vs 상업영화 | 가족 vs 공연: WEAT score = 0.2225
# 예술영화 vs 상업영화 | 가족 vs 공포(호러): WEAT score = -0.1435
# 예술영화 vs 상업영화 | 가족 vs 기타: WEAT score = 0.7582
# 예술영화 vs 상업영화 | 가족 vs 다큐멘터리: WEAT score = 0.8296
# 예술영화 vs 상업영화 | 가족 vs 드라마: WEAT score = 0.2513
# 예술영화 vs 상업영화 | 가족 vs 멜로로맨스: WEAT score = -0.6112
# 예술영화 vs 상업영화 | 가족 vs 뮤지컬: WEAT score = 0.7145
# 예술영화 vs 상업영화 | 가족 vs 미스터리: WEAT score = -0.2869
# 예술영화 vs 상업영화 | 가족 vs 범죄: WEAT score = 0.2698
# 예술영화 vs 상업영화 | 가족 vs 사극: WEAT score = -0.0580
# 예술영화 vs 상업영화 | 가족 vs 서부극(웨스턴): WEAT score = 0.3976
# 예술영화 vs 상업영화 | 가족 vs 성인물(에로): WEAT score = -0.2837
# 예술영화 vs 상업영화 | 가족 vs 스릴러: WEAT score = -0.1035
# 예술영화 vs 상업영화 | 가족 vs 애니메이션: WEAT score = 0.8656
# 예술영화 vs 상업영화 | 가족 vs 액션: WEAT score = 0.1358
# 예술영화 vs 상업영화 | 가족 vs 어드벤처: WEAT score = -0.0204
# 예술영화 vs 상업영화 | 가족 vs 전쟁: WEAT score = 0.6221
# 예술영화 vs 상업영화 | 가족 vs 코미디: WEAT score = 0.2304
# 예술영화 vs 상업영화 | 가족 vs 판타지: WEAT score = 0.4531
# 예술영화 vs 상업영화 | 공연 vs 공포(호러): WEAT score = -0.2506
# 예술영화 vs 상업영화 | 공연 vs 기타: WEAT score = 0.9319
# 예술영화 vs 상업영화 | 공연 vs 다큐멘터리: WEAT score = 0.9149
# 예술영화 vs 상업영화 | 공연 vs 드라마: WEAT score = -0.0115
# 예술영화 vs 상업영화 | 공연 vs 멜로로맨스: WEAT score = -0.6993
# 예술영화 vs 상업영화 | 공연 vs 뮤지컬: WEAT score = 0.8922
# 예술영화 vs 상업영화 | 공연 vs 미스터리: WEAT score = -0.3505
# 예술영화 vs 상업영화 | 공연 vs 범죄: WEAT score = 0.1044
# 예술영화 vs 상업영화 | 공연 vs 사극: WEAT score = -0.3867
# 예술영화 vs 상업영화 | 공연 vs 서부극(웨스턴): WEAT score = -0.0115
# 예술영화 vs 상업영화 | 공연 vs 성인물(에로): WEAT score = -0.4627
# 예술영화 vs 상업영화 | 공연 vs 스릴러: WEAT score = -0.2057
# 예술영화 vs 상업영화 | 공연 vs 애니메이션: WEAT score = 0.9022
# 예술영화 vs 상업영화 | 공연 vs 액션: WEAT score = -0.0357
# 예술영화 vs 상업영화 | 공연 vs 어드벤처: WEAT score = -0.2360
# 예술영화 vs 상업영화 | 공연 vs 전쟁: WEAT score = 0.5332
# 예술영화 vs 상업영화 | 공연 vs 코미디: WEAT score = -0.0239
# 예술영화 vs 상업영화 | 공연 vs 판타지: WEAT score = 0.3110
# 예술영화 vs 상업영화 | 공포(호러) vs 기타: WEAT score = 0.6391
# 예술영화 vs 상업영화 | 공포(호러) vs 다큐멘터리: WEAT score = 0.7355
# 예술영화 vs 상업영화 | 공포(호러) vs 드라마: WEAT score = 0.3059
# 예술영화 vs 상업영화 | 공포(호러) vs 멜로로맨스: WEAT score = -0.6097
# 예술영화 vs 상업영화 | 공포(호러) vs 뮤지컬: WEAT score = 0.6171
# 예술영화 vs 상업영화 | 공포(호러) vs 미스터리: WEAT score = -0.5544
# 예술영화 vs 상업영화 | 공포(호러) vs 범죄: WEAT score = 0.6984
# 예술영화 vs 상업영화 | 공포(호러) vs 사극: WEAT score = 0.1073
# 예술영화 vs 상업영화 | 공포(호러) vs 서부극(웨스턴): WEAT score = 0.3880
# 예술영화 vs 상업영화 | 공포(호러) vs 성인물(에로): WEAT score = -0.1936
# 예술영화 vs 상업영화 | 공포(호러) vs 스릴러: WEAT score = 0.0397
# 예술영화 vs 상업영화 | 공포(호러) vs 애니메이션: WEAT score = 0.6593
# 예술영화 vs 상업영화 | 공포(호러) vs 액션: WEAT score = 0.5323
# 예술영화 vs 상업영화 | 공포(호러) vs 어드벤처: WEAT score = 0.1557
# 예술영화 vs 상업영화 | 공포(호러) vs 전쟁: WEAT score = 0.6196
# 예술영화 vs 상업영화 | 공포(호러) vs 코미디: WEAT score = 0.4213
# 예술영화 vs 상업영화 | 공포(호러) vs 판타지: WEAT score = 0.5190
# 예술영화 vs 상업영화 | 기타 vs 다큐멘터리: WEAT score = 0.5509
# 예술영화 vs 상업영화 | 기타 vs 드라마: WEAT score = -0.8870
# 예술영화 vs 상업영화 | 기타 vs 멜로로맨스: WEAT score = -0.8912
# 예술영화 vs 상업영화 | 기타 vs 뮤지컬: WEAT score = 0.0185
# 예술영화 vs 상업영화 | 기타 vs 미스터리: WEAT score = -0.6568
# 예술영화 vs 상업영화 | 기타 vs 범죄: WEAT score = -0.3655
# 예술영화 vs 상업영화 | 기타 vs 사극: WEAT score = -0.8340
# 예술영화 vs 상업영화 | 기타 vs 서부극(웨스턴): WEAT score = -0.6389
# 예술영화 vs 상업영화 | 기타 vs 성인물(에로): WEAT score = -0.8089
# 예술영화 vs 상업영화 | 기타 vs 스릴러: WEAT score = -0.5539
# 예술영화 vs 상업영화 | 기타 vs 애니메이션: WEAT score = -0.0875
# 예술영화 vs 상업영화 | 기타 vs 액션: WEAT score = -0.4794
# 예술영화 vs 상업영화 | 기타 vs 어드벤처: WEAT score = -0.7943
# 예술영화 vs 상업영화 | 기타 vs 전쟁: WEAT score = -0.2492
# 예술영화 vs 상업영화 | 기타 vs 코미디: WEAT score = -0.7384
# 예술영화 vs 상업영화 | 기타 vs 판타지: WEAT score = -0.6889
# 예술영화 vs 상업영화 | 다큐멘터리 vs 드라마: WEAT score = -0.9018
# 예술영화 vs 상업영화 | 다큐멘터리 vs 멜로로맨스: WEAT score = -0.8878
# 예술영화 vs 상업영화 | 다큐멘터리 vs 뮤지컬: WEAT score = -0.6842
# 예술영화 vs 상업영화 | 다큐멘터리 vs 미스터리: WEAT score = -0.7392
# 예술영화 vs 상업영화 | 다큐멘터리 vs 범죄: WEAT score = -0.4835
# 예술영화 vs 상업영화 | 다큐멘터리 vs 사극: WEAT score = -0.9060
# 예술영화 vs 상업영화 | 다큐멘터리 vs 서부극(웨스턴): WEAT score = -0.7361
# 예술영화 vs 상업영화 | 다큐멘터리 vs 성인물(에로): WEAT score = -0.8156
# 예술영화 vs 상업영화 | 다큐멘터리 vs 스릴러: WEAT score = -0.6378
# 예술영화 vs 상업영화 | 다큐멘터리 vs 애니메이션: WEAT score = -0.5205
# 예술영화 vs 상업영화 | 다큐멘터리 vs 액션: WEAT score = -0.6016
# 예술영화 vs 상업영화 | 다큐멘터리 vs 어드벤처: WEAT score = -0.9363
# 예술영화 vs 상업영화 | 다큐멘터리 vs 전쟁: WEAT score = -0.4495
# 예술영화 vs 상업영화 | 다큐멘터리 vs 코미디: WEAT score = -0.8136
# 예술영화 vs 상업영화 | 다큐멘터리 vs 판타지: WEAT score = -0.8781
# 예술영화 vs 상업영화 | 드라마 vs 멜로로맨스: WEAT score = -0.8299
# 예술영화 vs 상업영화 | 드라마 vs 뮤지컬: WEAT score = 0.8264
# 예술영화 vs 상업영화 | 드라마 vs 미스터리: WEAT score = -0.4122
# 예술영화 vs 상업영화 | 드라마 vs 범죄: WEAT score = 0.1154
# 예술영화 vs 상업영화 | 드라마 vs 사극: WEAT score = -0.3447
# 예술영화 vs 상업영화 | 드라마 vs 서부극(웨스턴): WEAT score = -0.0034
# 예술영화 vs 상업영화 | 드라마 vs 성인물(에로): WEAT score = -0.5577
# 예술영화 vs 상업영화 | 드라마 vs 스릴러: WEAT score = -0.2309
# 예술영화 vs 상업영화 | 드라마 vs 애니메이션: WEAT score = 0.8822
# 예술영화 vs 상업영화 | 드라마 vs 액션: WEAT score = -0.0331
# 예술영화 vs 상업영화 | 드라마 vs 어드벤처: WEAT score = -0.3036
# 예술영화 vs 상업영화 | 드라마 vs 전쟁: WEAT score = 0.4322
# 예술영화 vs 상업영화 | 드라마 vs 코미디: WEAT score = -0.0290
# 예술영화 vs 상업영화 | 드라마 vs 판타지: WEAT score = 0.5184
# 예술영화 vs 상업영화 | 멜로로맨스 vs 뮤지컬: WEAT score = 0.8594
# 예술영화 vs 상업영화 | 멜로로맨스 vs 미스터리: WEAT score = 0.4510
# 예술영화 vs 상업영화 | 멜로로맨스 vs 범죄: WEAT score = 0.8422
# 예술영화 vs 상업영화 | 멜로로맨스 vs 사극: WEAT score = 0.6206
# 예술영화 vs 상업영화 | 멜로로맨스 vs 서부극(웨스턴): WEAT score = 0.7246
# 예술영화 vs 상업영화 | 멜로로맨스 vs 성인물(에로): WEAT score = 0.8465
# 예술영화 vs 상업영화 | 멜로로맨스 vs 스릴러: WEAT score = 0.6490
# 예술영화 vs 상업영화 | 멜로로맨스 vs 애니메이션: WEAT score = 0.8742
# 예술영화 vs 상업영화 | 멜로로맨스 vs 액션: WEAT score = 0.7200
# 예술영화 vs 상업영화 | 멜로로맨스 vs 어드벤처: WEAT score = 0.5820
# 예술영화 vs 상업영화 | 멜로로맨스 vs 전쟁: WEAT score = 0.7672
# 예술영화 vs 상업영화 | 멜로로맨스 vs 코미디: WEAT score = 0.8889
# 예술영화 vs 상업영화 | 멜로로맨스 vs 판타지: WEAT score = 0.8228
# 예술영화 vs 상업영화 | 뮤지컬 vs 미스터리: WEAT score = -0.6393
# 예술영화 vs 상업영화 | 뮤지컬 vs 범죄: WEAT score = -0.3515
# 예술영화 vs 상업영화 | 뮤지컬 vs 사극: WEAT score = -0.8112
# 예술영화 vs 상업영화 | 뮤지컬 vs 서부극(웨스턴): WEAT score = -0.5995
# 예술영화 vs 상업영화 | 뮤지컬 vs 성인물(에로): WEAT score = -0.7794
# 예술영화 vs 상업영화 | 뮤지컬 vs 스릴러: WEAT score = -0.5351
# 예술영화 vs 상업영화 | 뮤지컬 vs 애니메이션: WEAT score = -0.0750
# 예술영화 vs 상업영화 | 뮤지컬 vs 액션: WEAT score = -0.4668
# 예술영화 vs 상업영화 | 뮤지컬 vs 어드벤처: WEAT score = -0.7818
# 예술영화 vs 상업영화 | 뮤지컬 vs 전쟁: WEAT score = -0.2390
# 예술영화 vs 상업영화 | 뮤지컬 vs 코미디: WEAT score = -0.6948
# 예술영화 vs 상업영화 | 뮤지컬 vs 판타지: WEAT score = -0.6742
# 예술영화 vs 상업영화 | 미스터리 vs 범죄: WEAT score = 1.0073
# 예술영화 vs 상업영화 | 미스터리 vs 사극: WEAT score = 0.2679
# 예술영화 vs 상업영화 | 미스터리 vs 서부극(웨스턴): WEAT score = 0.4818
# 예술영화 vs 상업영화 | 미스터리 vs 성인물(에로): WEAT score = -0.0277
# 예술영화 vs 상업영화 | 미스터리 vs 스릴러: WEAT score = 0.7645
# 예술영화 vs 상업영화 | 미스터리 vs 애니메이션: WEAT score = 0.6661
# 예술영화 vs 상업영화 | 미스터리 vs 액션: WEAT score = 0.7635
# 예술영화 vs 상업영화 | 미스터리 vs 어드벤처: WEAT score = 0.2980
# 예술영화 vs 상업영화 | 미스터리 vs 전쟁: WEAT score = 0.6485
# 예술영화 vs 상업영화 | 미스터리 vs 코미디: WEAT score = 0.5223
# 예술영화 vs 상업영화 | 미스터리 vs 판타지: WEAT score = 0.5605
# 예술영화 vs 상업영화 | 범죄 vs 사극: WEAT score = -0.3562
# 예술영화 vs 상업영화 | 범죄 vs 서부극(웨스턴): WEAT score = -0.1622
# 예술영화 vs 상업영화 | 범죄 vs 성인물(에로): WEAT score = -0.4912
# 예술영화 vs 상업영화 | 범죄 vs 스릴러: WEAT score = -0.9586
# 예술영화 vs 상업영화 | 범죄 vs 애니메이션: WEAT score = 0.3624
# 예술영화 vs 상업영화 | 범죄 vs 액션: WEAT score = -0.4517
# 예술영화 vs 상업영화 | 범죄 vs 어드벤처: WEAT score = -0.2769
# 예술영화 vs 상업영화 | 범죄 vs 전쟁: WEAT score = 0.3152
# 예술영화 vs 상업영화 | 범죄 vs 코미디: WEAT score = -0.1571
# 예술영화 vs 상업영화 | 범죄 vs 판타지: WEAT score = 0.0602
# 예술영화 vs 상업영화 | 사극 vs 서부극(웨스턴): WEAT score = 0.3741
# 예술영화 vs 상업영화 | 사극 vs 성인물(에로): WEAT score = -0.2813
# 예술영화 vs 상업영화 | 사극 vs 스릴러: WEAT score = -0.0673
# 예술영화 vs 상업영화 | 사극 vs 애니메이션: WEAT score = 0.8392
# 예술영화 vs 상업영화 | 사극 vs 액션: WEAT score = 0.2173
# 예술영화 vs 상업영화 | 사극 vs 어드벤처: WEAT score = 0.0611
# 예술영화 vs 상업영화 | 사극 vs 전쟁: WEAT score = 0.8436
# 예술영화 vs 상업영화 | 사극 vs 코미디: WEAT score = 0.4303
# 예술영화 vs 상업영화 | 사극 vs 판타지: WEAT score = 0.6586
# 예술영화 vs 상업영화 | 서부극(웨스턴) vs 성인물(에로): WEAT score = -0.4040
# 예술영화 vs 상업영화 | 서부극(웨스턴) vs 스릴러: WEAT score = -0.2898
# 예술영화 vs 상업영화 | 서부극(웨스턴) vs 애니메이션: WEAT score = 0.7083
# 예술영화 vs 상업영화 | 서부극(웨스턴) vs 액션: WEAT score = -0.0483
# 예술영화 vs 상업영화 | 서부극(웨스턴) vs 어드벤처: WEAT score = -0.3384
# 예술영화 vs 상업영화 | 서부극(웨스턴) vs 전쟁: WEAT score = 0.6388
# 예술영화 vs 상업영화 | 서부극(웨스턴) vs 코미디: WEAT score = -0.0128
# 예술영화 vs 상업영화 | 서부극(웨스턴) vs 판타지: WEAT score = 0.2842
# 예술영화 vs 상업영화 | 성인물(에로) vs 스릴러: WEAT score = 0.2057
# 예술영화 vs 상업영화 | 성인물(에로) vs 애니메이션: WEAT score = 0.7563
# 예술영화 vs 상업영화 | 성인물(에로) vs 액션: WEAT score = 0.3576
# 예술영화 vs 상업영화 | 성인물(에로) vs 어드벤처: WEAT score = 0.2691
# 예술영화 vs 상업영화 | 성인물(에로) vs 전쟁: WEAT score = 0.5691
# 예술영화 vs 상업영화 | 성인물(에로) vs 코미디: WEAT score = 0.5541
# 예술영화 vs 상업영화 | 성인물(에로) vs 판타지: WEAT score = 0.6055
# 예술영화 vs 상업영화 | 스릴러 vs 애니메이션: WEAT score = 0.5613
# 예술영화 vs 상업영화 | 스릴러 vs 액션: WEAT score = 0.4764
# 예술영화 vs 상업영화 | 스릴러 vs 어드벤처: WEAT score = 0.0930
# 예술영화 vs 상업영화 | 스릴러 vs 전쟁: WEAT score = 0.5447
# 예술영화 vs 상업영화 | 스릴러 vs 코미디: WEAT score = 0.2864
# 예술영화 vs 상업영화 | 스릴러 vs 판타지: WEAT score = 0.3775
# 예술영화 vs 상업영화 | 애니메이션 vs 액션: WEAT score = -0.4918
# 예술영화 vs 상업영화 | 애니메이션 vs 어드벤처: WEAT score = -0.8726
# 예술영화 vs 상업영화 | 애니메이션 vs 전쟁: WEAT score = -0.2482
# 예술영화 vs 상업영화 | 애니메이션 vs 코미디: WEAT score = -0.7408
# 예술영화 vs 상업영화 | 애니메이션 vs 판타지: WEAT score = -0.6882
# 예술영화 vs 상업영화 | 액션 vs 어드벤처: WEAT score = -0.1580
# 예술영화 vs 상업영화 | 액션 vs 전쟁: WEAT score = 0.5200
# 예술영화 vs 상업영화 | 액션 vs 코미디: WEAT score = 0.0323
# 예술영화 vs 상업영화 | 액션 vs 판타지: WEAT score = 0.2247
# 예술영화 vs 상업영화 | 어드벤처 vs 전쟁: WEAT score = 0.6484
# 예술영화 vs 상업영화 | 어드벤처 vs 코미디: WEAT score = 0.3399
# 예술영화 vs 상업영화 | 어드벤처 vs 판타지: WEAT score = 0.7626
# 예술영화 vs 상업영화 | 전쟁 vs 코미디: WEAT score = -0.4785
# 예술영화 vs 상업영화 | 전쟁 vs 판타지: WEAT score = -0.2524
# 예술영화 vs 상업영화 | 코미디 vs 판타지: WEAT score = 0.5073

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

np.random.seed(0)

# 한글 지원 폰트
sns.set(font='NanumGothic')

# 마이너스 부호 
plt.rcParams['axes.unicode_minus'] = False
plt.figure(figsize=(12, 10))

ax = sns.heatmap(matrix_tfidf, xticklabels=genre_name, yticklabels=genre_name, annot=True,  cmap='RdYlGn_r')
#ax

plt.title('장르 간 WEAT Score (TF-IDF 기반)', fontsize=18)
plt.tight_layout()
plt.show()

plt.savefig('weat_score_heatmap_tfidf.png', dpi=100, bbox_inches='tight')

# %% [markdown]
# ## 3. 중심벡터 유사도 방식으로  단어셋 추출

# %%
target_art_2, target_gen_2 = [], []

# 토큰으로 embedding model 만들기
model_art = Word2Vec(art_tokens, vector_size=100, window=5, min_count=3, sg=0) 
# 중심 벡터
vector_mean = np.mean([model_art.wv[word] for word in model_art.wv.index_to_key], axis=0)

# 중심 벡터에 가장 가까운 단어들
representative_words = model_art.wv.similar_by_vector(vector_mean, topn=20)
target_art_2 = [word for word, _ in representative_words]
print("art 대표 단어:", target_art_2)
# Out:
# art 대표 단어: ['쟈', '땡', '꿋', '뽀', '퐁', '쿵', '흠', '틈', '빡', '싹', '컥', '앳', '뻑', '볕', '쭈', '겔', '돔', '샅', '갬', '텅']

# %%
# 대표 단어 추출
target_art_2 = get_representative_words(art_tokens)
target_gen_2 = get_representative_words(gen_tokens)

print("예술영화 대표 단어:", target_art_2)
print("상업영화 대표 단어:", target_gen_2)
# Out:
# 예술영화 대표 단어: ['앳', '쿵', '갬', '샅', '꿋', '듬', '뿍', '똘', '잎', '꿍', '씬', '헛', '꽁', '흠', '뻑']
# 상업영화 대표 단어: ['킵', '끙', '챵', '츤', '넵', '찹', '쫀', '쏙', '웩', '쩔', '낄', '훅', '떳', '텡', '휑']

# %% [markdown]
# - 중심 단어가 한자리 단어로 이상하게 나옴
# - 벡터를 만들때마다 달라짐
# - 중심단어의 주변 단어들로 뽑아보는 것이 좋을까?

# %%
attribute_sets = []
attribute_sets = {g: genre_tokens_dict[g]['representative_words'] for g in genre_name}

matrix_meanvt = compute_weat_matrix(
    genre_names=genre_name,
    attribute_sets=attribute_sets, # 중심벡터 유사도로 추출한 단어들
    target_art=target_art_2,
    target_gen=target_gen_2,
    model=model_all
)
# Out:
# 예술영화 vs 상업영화 | SF vs 가족: WEAT score = -0.1072
# 예술영화 vs 상업영화 | SF vs 공연: WEAT score = -0.0084
# 예술영화 vs 상업영화 | SF vs 공포(호러): WEAT score = -0.3815
# 예술영화 vs 상업영화 | SF vs 기타: WEAT score = -0.0441
# 예술영화 vs 상업영화 | SF vs 다큐멘터리: WEAT score = -0.2067
# 예술영화 vs 상업영화 | SF vs 드라마: WEAT score = -0.2048
# 예술영화 vs 상업영화 | SF vs 멜로로맨스: WEAT score = -0.1549
# 예술영화 vs 상업영화 | SF vs 뮤지컬: WEAT score = -0.0927
# 예술영화 vs 상업영화 | SF vs 미스터리: WEAT score = -0.2640
# 예술영화 vs 상업영화 | SF vs 범죄: WEAT score = -0.0001
# 예술영화 vs 상업영화 | SF vs 사극: WEAT score = -0.1046
# 예술영화 vs 상업영화 | SF vs 서부극(웨스턴): WEAT score = -0.2832
# 예술영화 vs 상업영화 | SF vs 성인물(에로): WEAT score = -0.1705
# 예술영화 vs 상업영화 | SF vs 스릴러: WEAT score = -0.1957
# 예술영화 vs 상업영화 | SF vs 애니메이션: WEAT score = -0.0926
# 예술영화 vs 상업영화 | SF vs 액션: WEAT score = -0.0998
# 예술영화 vs 상업영화 | SF vs 어드벤처: WEAT score = -0.7344
# 예술영화 vs 상업영화 | SF vs 전쟁: WEAT score = 0.4268
# 예술영화 vs 상업영화 | SF vs 코미디: WEAT score = -0.3508
# 예술영화 vs 상업영화 | SF vs 판타지: WEAT score = -0.4591
# 예술영화 vs 상업영화 | 가족 vs 공연: WEAT score = 0.3092
# 예술영화 vs 상업영화 | 가족 vs 공포(호러): WEAT score = -0.1774
# 예술영화 vs 상업영화 | 가족 vs 기타: WEAT score = 0.1183
# 예술영화 vs 상업영화 | 가족 vs 다큐멘터리: WEAT score = 0.0024
# 예술영화 vs 상업영화 | 가족 vs 드라마: WEAT score = -0.3707
# 예술영화 vs 상업영화 | 가족 vs 멜로로맨스: WEAT score = -0.2644
# 예술영화 vs 상업영화 | 가족 vs 뮤지컬: WEAT score = 0.0581
# 예술영화 vs 상업영화 | 가족 vs 미스터리: WEAT score = -0.1707
# 예술영화 vs 상업영화 | 가족 vs 범죄: WEAT score = 0.1899
# 예술영화 vs 상업영화 | 가족 vs 사극: WEAT score = 0.0996
# 예술영화 vs 상업영화 | 가족 vs 서부극(웨스턴): WEAT score = -0.1731
# 예술영화 vs 상업영화 | 가족 vs 성인물(에로): WEAT score = -0.3362
# 예술영화 vs 상업영화 | 가족 vs 스릴러: WEAT score = -0.1440
# 예술영화 vs 상업영화 | 가족 vs 애니메이션: WEAT score = 0.0661
# 예술영화 vs 상업영화 | 가족 vs 액션: WEAT score = 0.0856
# 예술영화 vs 상업영화 | 가족 vs 어드벤처: WEAT score = -0.2838
# 예술영화 vs 상업영화 | 가족 vs 전쟁: WEAT score = 0.3022
# 예술영화 vs 상업영화 | 가족 vs 코미디: WEAT score = -0.3041
# 예술영화 vs 상업영화 | 가족 vs 판타지: WEAT score = -0.1682
# 예술영화 vs 상업영화 | 공연 vs 공포(호러): WEAT score = -0.2883
# 예술영화 vs 상업영화 | 공연 vs 기타: WEAT score = -0.0780
# 예술영화 vs 상업영화 | 공연 vs 다큐멘터리: WEAT score = -0.1327
# 예술영화 vs 상업영화 | 공연 vs 드라마: WEAT score = -0.6709
# 예술영화 vs 상업영화 | 공연 vs 멜로로맨스: WEAT score = -0.3147
# 예술영화 vs 상업영화 | 공연 vs 뮤지컬: WEAT score = -0.2003
# 예술영화 vs 상업영화 | 공연 vs 미스터리: WEAT score = -0.2939
# 예술영화 vs 상업영화 | 공연 vs 범죄: WEAT score = 0.0146
# 예술영화 vs 상업영화 | 공연 vs 사극: WEAT score = -0.0800
# 예술영화 vs 상업영화 | 공연 vs 서부극(웨스턴): WEAT score = -0.3252
# 예술영화 vs 상업영화 | 공연 vs 성인물(에로): WEAT score = -0.4087
# 예술영화 vs 상업영화 | 공연 vs 스릴러: WEAT score = -0.2893
# 예술영화 vs 상업영화 | 공연 vs 애니메이션: WEAT score = -0.1525
# 예술영화 vs 상업영화 | 공연 vs 액션: WEAT score = -0.0854
# 예술영화 vs 상업영화 | 공연 vs 어드벤처: WEAT score = -0.3930
# 예술영화 vs 상업영화 | 공연 vs 전쟁: WEAT score = 0.2331
# 예술영화 vs 상업영화 | 공연 vs 코미디: WEAT score = -0.4933
# 예술영화 vs 상업영화 | 공연 vs 판타지: WEAT score = -0.3434
# 예술영화 vs 상업영화 | 공포(호러) vs 기타: WEAT score = 0.2187
# 예술영화 vs 상업영화 | 공포(호러) vs 다큐멘터리: WEAT score = 0.1471
# 예술영화 vs 상업영화 | 공포(호러) vs 드라마: WEAT score = 0.0760
# 예술영화 vs 상업영화 | 공포(호러) vs 멜로로맨스: WEAT score = 0.0170
# 예술영화 vs 상업영화 | 공포(호러) vs 뮤지컬: WEAT score = 0.1863
# 예술영화 vs 상업영화 | 공포(호러) vs 미스터리: WEAT score = 0.1088
# 예술영화 vs 상업영화 | 공포(호러) vs 범죄: WEAT score = 0.5639
# 예술영화 vs 상업영화 | 공포(호러) vs 사극: WEAT score = 0.5714
# 예술영화 vs 상업영화 | 공포(호러) vs 서부극(웨스턴): WEAT score = 0.1562
# 예술영화 vs 상업영화 | 공포(호러) vs 성인물(에로): WEAT score = -0.0138
# 예술영화 vs 상업영화 | 공포(호러) vs 스릴러: WEAT score = 0.1407
# 예술영화 vs 상업영화 | 공포(호러) vs 애니메이션: WEAT score = 0.2032
# 예술영화 vs 상업영화 | 공포(호러) vs 액션: WEAT score = 0.7518
# 예술영화 vs 상업영화 | 공포(호러) vs 어드벤처: WEAT score = -0.3729
# 예술영화 vs 상업영화 | 공포(호러) vs 전쟁: WEAT score = 0.5850
# 예술영화 vs 상업영화 | 공포(호러) vs 코미디: WEAT score = -0.0252
# 예술영화 vs 상업영화 | 공포(호러) vs 판타지: WEAT score = 0.0422
# 예술영화 vs 상업영화 | 기타 vs 다큐멘터리: WEAT score = -0.1429
# 예술영화 vs 상업영화 | 기타 vs 드라마: WEAT score = -0.3188
# 예술영화 vs 상업영화 | 기타 vs 멜로로맨스: WEAT score = -0.1803
# 예술영화 vs 상업영화 | 기타 vs 뮤지컬: WEAT score = -0.2946
# 예술영화 vs 상업영화 | 기타 vs 미스터리: WEAT score = -0.1930
# 예술영화 vs 상업영화 | 기타 vs 범죄: WEAT score = 0.0518
# 예술영화 vs 상업영화 | 기타 vs 사극: WEAT score = -0.0222
# 예술영화 vs 상업영화 | 기타 vs 서부극(웨스턴): WEAT score = -0.2152
# 예술영화 vs 상업영화 | 기타 vs 성인물(에로): WEAT score = -0.2329
# 예술영화 vs 상업영화 | 기타 vs 스릴러: WEAT score = -0.1662
# 예술영화 vs 상업영화 | 기타 vs 애니메이션: WEAT score = -0.2468
# 예술영화 vs 상업영화 | 기타 vs 액션: WEAT score = -0.0289
# 예술영화 vs 상업영화 | 기타 vs 어드벤처: WEAT score = -0.3475
# 예술영화 vs 상업영화 | 기타 vs 전쟁: WEAT score = 0.3251
# 예술영화 vs 상업영화 | 기타 vs 코미디: WEAT score = -0.3445
# 예술영화 vs 상업영화 | 기타 vs 판타지: WEAT score = -0.3102
# 예술영화 vs 상업영화 | 다큐멘터리 vs 드라마: WEAT score = -0.1004
# 예술영화 vs 상업영화 | 다큐멘터리 vs 멜로로맨스: WEAT score = -0.0799
# 예술영화 vs 상업영화 | 다큐멘터리 vs 뮤지컬: WEAT score = 0.0689
# 예술영화 vs 상업영화 | 다큐멘터리 vs 미스터리: WEAT score = -0.1048
# 예술영화 vs 상업영화 | 다큐멘터리 vs 범죄: WEAT score = 0.1325
# 예술영화 vs 상업영화 | 다큐멘터리 vs 사극: WEAT score = 0.0923
# 예술영화 vs 상업영화 | 다큐멘터리 vs 서부극(웨스턴): WEAT score = -0.1107
# 예술영화 vs 상업영화 | 다큐멘터리 vs 성인물(에로): WEAT score = -0.1054
# 예술영화 vs 상업영화 | 다큐멘터리 vs 스릴러: WEAT score = -0.0693
# 예술영화 vs 상업영화 | 다큐멘터리 vs 애니메이션: WEAT score = 0.0845
# 예술영화 vs 상업영화 | 다큐멘터리 vs 액션: WEAT score = 0.0646
# 예술영화 vs 상업영화 | 다큐멘터리 vs 어드벤처: WEAT score = -0.3195
# 예술영화 vs 상업영화 | 다큐멘터리 vs 전쟁: WEAT score = 0.7707
# 예술영화 vs 상업영화 | 다큐멘터리 vs 코미디: WEAT score = -0.1938
# 예술영화 vs 상업영화 | 다큐멘터리 vs 판타지: WEAT score = -0.2203
# 예술영화 vs 상업영화 | 드라마 vs 멜로로맨스: WEAT score = -0.0521
# 예술영화 vs 상업영화 | 드라마 vs 뮤지컬: WEAT score = 0.2510
# 예술영화 vs 상업영화 | 드라마 vs 미스터리: WEAT score = -0.0400
# 예술영화 vs 상업영화 | 드라마 vs 범죄: WEAT score = 0.3505
# 예술영화 vs 상업영화 | 드라마 vs 사극: WEAT score = 0.2786
# 예술영화 vs 상업영화 | 드라마 vs 서부극(웨스턴): WEAT score = -0.0252
# 예술영화 vs 상업영화 | 드라마 vs 성인물(에로): WEAT score = -0.1079
# 예술영화 vs 상업영화 | 드라마 vs 스릴러: WEAT score = 0.0177
# 예술영화 vs 상업영화 | 드라마 vs 애니메이션: WEAT score = 0.2679
# 예술영화 vs 상업영화 | 드라마 vs 액션: WEAT score = 0.2400
# 예술영화 vs 상업영화 | 드라마 vs 어드벤처: WEAT score = -0.2176
# 예술영화 vs 상업영화 | 드라마 vs 전쟁: WEAT score = 0.4531
# 예술영화 vs 상업영화 | 드라마 vs 코미디: WEAT score = -0.1827
# 예술영화 vs 상업영화 | 드라마 vs 판타지: WEAT score = -0.0654
# 예술영화 vs 상업영화 | 멜로로맨스 vs 뮤지컬: WEAT score = 0.1434
# 예술영화 vs 상업영화 | 멜로로맨스 vs 미스터리: WEAT score = 0.0118
# 예술영화 vs 상업영화 | 멜로로맨스 vs 범죄: WEAT score = 0.2504
# 예술영화 vs 상업영화 | 멜로로맨스 vs 사극: WEAT score = 0.1762
# 예술영화 vs 상업영화 | 멜로로맨스 vs 서부극(웨스턴): WEAT score = 0.0248
# 예술영화 vs 상업영화 | 멜로로맨스 vs 성인물(에로): WEAT score = -0.1353
# 예술영화 vs 상업영화 | 멜로로맨스 vs 스릴러: WEAT score = 0.0584
# 예술영화 vs 상업영화 | 멜로로맨스 vs 애니메이션: WEAT score = 0.1471
# 예술영화 vs 상업영화 | 멜로로맨스 vs 액션: WEAT score = 0.1739
# 예술영화 vs 상업영화 | 멜로로맨스 vs 어드벤처: WEAT score = -0.1021
# 예술영화 vs 상업영화 | 멜로로맨스 vs 전쟁: WEAT score = 0.2954
# 예술영화 vs 상업영화 | 멜로로맨스 vs 코미디: WEAT score = -0.0316
# 예술영화 vs 상업영화 | 멜로로맨스 vs 판타지: WEAT score = -0.0001
# 예술영화 vs 상업영화 | 뮤지컬 vs 미스터리: WEAT score = -0.1584
# 예술영화 vs 상업영화 | 뮤지컬 vs 범죄: WEAT score = 0.1116
# 예술영화 vs 상업영화 | 뮤지컬 vs 사극: WEAT score = 0.0417
# 예술영화 vs 상업영화 | 뮤지컬 vs 서부극(웨스턴): WEAT score = -0.1770
# 예술영화 vs 상업영화 | 뮤지컬 vs 성인물(에로): WEAT score = -0.1904
# 예술영화 vs 상업영화 | 뮤지컬 vs 스릴러: WEAT score = -0.1272
# 예술영화 vs 상업영화 | 뮤지컬 vs 애니메이션: WEAT score = 0.0261
# 예술영화 vs 상업영화 | 뮤지컬 vs 액션: WEAT score = 0.0238
# 예술영화 vs 상업영화 | 뮤지컬 vs 어드벤처: WEAT score = -0.3234
# 예술영화 vs 상업영화 | 뮤지컬 vs 전쟁: WEAT score = 0.4178
# 예술영화 vs 상업영화 | 뮤지컬 vs 코미디: WEAT score = -0.3066
# 예술영화 vs 상업영화 | 뮤지컬 vs 판타지: WEAT score = -0.2672
# 예술영화 vs 상업영화 | 미스터리 vs 범죄: WEAT score = 0.7083
# 예술영화 vs 상업영화 | 미스터리 vs 사극: WEAT score = 0.4227
# 예술영화 vs 상업영화 | 미스터리 vs 서부극(웨스턴): WEAT score = 0.0461
# 예술영화 vs 상업영화 | 미스터리 vs 성인물(에로): WEAT score = -0.0450
# 예술영화 vs 상업영화 | 미스터리 vs 스릴러: WEAT score = 0.1665
# 예술영화 vs 상업영화 | 미스터리 vs 애니메이션: WEAT score = 0.1680
# 예술영화 vs 상업영화 | 미스터리 vs 액션: WEAT score = 0.6562
# 예술영화 vs 상업영화 | 미스터리 vs 어드벤처: WEAT score = -0.2641
# 예술영화 vs 상업영화 | 미스터리 vs 전쟁: WEAT score = 0.4846
# 예술영화 vs 상업영화 | 미스터리 vs 코미디: WEAT score = -0.1059
# 예술영화 vs 상업영화 | 미스터리 vs 판타지: WEAT score = -0.0191
# 예술영화 vs 상업영화 | 범죄 vs 사극: WEAT score = -0.1536
# 예술영화 vs 상업영화 | 범죄 vs 서부극(웨스턴): WEAT score = -0.5909
# 예술영화 vs 상업영화 | 범죄 vs 성인물(에로): WEAT score = -0.2713
# 예술영화 vs 상업영화 | 범죄 vs 스릴러: WEAT score = -0.6513
# 예술영화 vs 상업영화 | 범죄 vs 애니메이션: WEAT score = -0.1030
# 예술영화 vs 상업영화 | 범죄 vs 액션: WEAT score = -0.2723
# 예술영화 vs 상업영화 | 범죄 vs 어드벤처: WEAT score = -0.5755
# 예술영화 vs 상업영화 | 범죄 vs 전쟁: WEAT score = 0.2747
# 예술영화 vs 상업영화 | 범죄 vs 코미디: WEAT score = -0.6630
# 예술영화 vs 상업영화 | 범죄 vs 판타지: WEAT score = -0.4253
# 예술영화 vs 상업영화 | 사극 vs 서부극(웨스턴): WEAT score = -0.5764
# 예술영화 vs 상업영화 | 사극 vs 성인물(에로): WEAT score = -0.1980
# 예술영화 vs 상업영화 | 사극 vs 스릴러: WEAT score = -0.2809
# 예술영화 vs 상업영화 | 사극 vs 애니메이션: WEAT score = -0.0341
# 예술영화 vs 상업영화 | 사극 vs 액션: WEAT score = -0.0409
# 예술영화 vs 상업영화 | 사극 vs 어드벤처: WEAT score = -0.9050
# 예술영화 vs 상업영화 | 사극 vs 전쟁: WEAT score = 0.4694
# 예술영화 vs 상업영화 | 사극 vs 코미디: WEAT score = -0.7729
# 예술영화 vs 상업영화 | 사극 vs 판타지: WEAT score = -0.6953
# 예술영화 vs 상업영화 | 서부극(웨스턴) vs 성인물(에로): WEAT score = -0.0580
# 예술영화 vs 상업영화 | 서부극(웨스턴) vs 스릴러: WEAT score = 0.0666
# 예술영화 vs 상업영화 | 서부극(웨스턴) vs 애니메이션: WEAT score = 0.1922
# 예술영화 vs 상업영화 | 서부극(웨스턴) vs 액션: WEAT score = 0.7047
# 예술영화 vs 상업영화 | 서부극(웨스턴) vs 어드벤처: WEAT score = -0.3768
# 예술영화 vs 상업영화 | 서부극(웨스턴) vs 전쟁: WEAT score = 0.5480
# 예술영화 vs 상업영화 | 서부극(웨스턴) vs 코미디: WEAT score = -0.2528
# 예술영화 vs 상업영화 | 서부극(웨스턴) vs 판타지: WEAT score = -0.0581
# 예술영화 vs 상업영화 | 성인물(에로) vs 스릴러: WEAT score = 0.0924
# 예술영화 vs 상업영화 | 성인물(에로) vs 애니메이션: WEAT score = 0.1914
# 예술영화 vs 상업영화 | 성인물(에로) vs 액션: WEAT score = 0.1930
# 예술영화 vs 상업영화 | 성인물(에로) vs 어드벤처: WEAT score = -0.0687
# 예술영화 vs 상업영화 | 성인물(에로) vs 전쟁: WEAT score = 0.3186
# 예술영화 vs 상업영화 | 성인물(에로) vs 코미디: WEAT score = 0.0075
# 예술영화 vs 상업영화 | 성인물(에로) vs 판타지: WEAT score = 0.0300
# 예술영화 vs 상업영화 | 스릴러 vs 애니메이션: WEAT score = 0.1342
# 예술영화 vs 상업영화 | 스릴러 vs 액션: WEAT score = 0.3728
# 예술영화 vs 상업영화 | 스릴러 vs 어드벤처: WEAT score = -0.2521
# 예술영화 vs 상업영화 | 스릴러 vs 전쟁: WEAT score = 0.4153
# 예술영화 vs 상업영화 | 스릴러 vs 코미디: WEAT score = -0.1838
# 예술영화 vs 상업영화 | 스릴러 vs 판타지: WEAT score = -0.0683
# 예술영화 vs 상업영화 | 애니메이션 vs 액션: WEAT score = 0.0175
# 예술영화 vs 상업영화 | 애니메이션 vs 어드벤처: WEAT score = -0.3560
# 예술영화 vs 상업영화 | 애니메이션 vs 전쟁: WEAT score = 0.4138
# 예술영화 vs 상업영화 | 애니메이션 vs 코미디: WEAT score = -0.3362
# 예술영화 vs 상업영화 | 애니메이션 vs 판타지: WEAT score = -0.3110
# 예술영화 vs 상업영화 | 액션 vs 어드벤처: WEAT score = -0.7421
# 예술영화 vs 상업영화 | 액션 vs 전쟁: WEAT score = 0.4054
# 예술영화 vs 상업영화 | 액션 vs 코미디: WEAT score = -0.6706
# 예술영화 vs 상업영화 | 액션 vs 판타지: WEAT score = -0.4313
# 예술영화 vs 상업영화 | 어드벤처 vs 전쟁: WEAT score = 0.8287
# 예술영화 vs 상업영화 | 어드벤처 vs 코미디: WEAT score = 0.2284
# 예술영화 vs 상업영화 | 어드벤처 vs 판타지: WEAT score = 0.4262
# 예술영화 vs 상업영화 | 전쟁 vs 코미디: WEAT score = -0.6567
# 예술영화 vs 상업영화 | 전쟁 vs 판타지: WEAT score = -0.8064
# 예술영화 vs 상업영화 | 코미디 vs 판타지: WEAT score = 0.0973

# %%
np.random.seed(0)

# 한글 지원 폰트
sns.set(font='NanumGothic')

# 마이너스 부호 
plt.rcParams['axes.unicode_minus'] = False
plt.figure(figsize=(12, 10))

ax = sns.heatmap(matrix_meanvt, xticklabels=genre_name, yticklabels=genre_name, annot=True,  cmap='RdYlGn_r')


plt.title('장르 간 WEAT Score (중심벡터 유사도 기반)', fontsize=18)
plt.tight_layout()
plt.show()

plt.savefig('weat_score_heatmap_meanvt.png', dpi=100, bbox_inches='tight')

# %% [markdown]
# ## 4. 잠재 의미 분석(Latent Semantic Analysis, LSA)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD

def extract_lsa_top_words(doc_str, n_components=1, topn=15, random_state=122):
    """
    주어진 텍스트로부터 TF-IDF 및 LSA를 이용해 대표 단어(topn개)를 추출합니다.

    Args:
        doc_str (str): 하나의 긴 텍스트 (공백으로 이어진 문장들)
        n_components (int): 추출할 주제 수 (LSA의 차원 수)
        topn (int): 각 주제에서 추출할 대표 단어 수
        random_state (int): SVD 재현성을 위한 random seed

    Returns:
        top_words (List[Tuple[str, float]]): 대표 단어와 점수 리스트
    """

    # 1. TF-IDF 벡터화
    vectorizer = TfidfVectorizer()
    tfidf_matrix = vectorizer.fit_transform([doc_str])
    print(f'TF-IDF 행렬의 크기: {tfidf_matrix.shape}')

    # 2. Truncated SVD (LSA)
    svd = TruncatedSVD(n_components=n_components, algorithm='randomized', n_iter=100, random_state=random_state)
    svd.fit(tfidf_matrix)
    print(f'추출된 topic 수: {len(svd.components_)}')

    # 3. 단어 목록
    terms = vectorizer.get_feature_names_out()

    # 4. 대표 단어 추출 함수
    def get_top_words_from_first_topic(components, terms, n):
        topic = components[0]
        indices = topic.argsort()[::-1][:n]
        return [(terms[i], topic[i]) for i in indices]

    # 5. 대표 단어 추출
    top_words = get_top_words_from_first_topic(svd.components_, terms, n=topn)

    # 6. 결과 출력
    print(f"Top {topn} words in Topic 1:")
    for word, score in top_words:
        print(f"{word}: {score:.5f}")

    return top_words

# %%
# art 
top_words = extract_lsa_top_words(art_str, topn=15)

# 단어만 뽑고 싶다면
art_attributes_set = [word for word, _ in top_words]
# Out:
# TF-IDF 행렬의 크기: (1, 18995)
# 추출된 topic 수: 1
# Top 15 words in Topic 1:
# 그녀: 0.30419
# 자신: 0.29475
# 시작: 0.29149
# 위해: 0.26083
# 사랑: 0.25467
# 사람: 0.23417
# 영화: 0.15654
# 친구: 0.15146
# 남자: 0.13386
# 가족: 0.11246
# 이야기: 0.10992
# 마을: 0.10484
# 사건: 0.09867
# 마음: 0.09795
# 세상: 0.09759
# /opt/conda/lib/python3.9/site-packages/sklearn/decomposition/_truncated_svd.py:234: RuntimeWarning: invalid value encountered in true_divide
#   self.explained_variance_ratio_ = exp_var / full_var

# %%
# gen
top_words = extract_lsa_top_words(gen_str, topn=15)

# 단어만 뽑고 싶다면
gen_attributes_set = [word for word, _ in top_words]
# Out:
# TF-IDF 행렬의 크기: (1, 37717)
# 추출된 topic 수: 1
# Top 15 words in Topic 1:
# 자신: 0.30275
# 그녀: 0.28809
# 영화제: 0.28794
# 위해: 0.23593
# 사람: 0.21279
# 시작: 0.21126
# 국제: 0.19611
# 영화: 0.17536
# 친구: 0.15766
# 사랑: 0.15610
# 남자: 0.14525
# 이야기: 0.12655
# 대한: 0.10264
# 서울: 0.10047
# 여자: 0.10021

# %% [markdown]
# - LSA에서도 단어 중복이 있음
# - 중복 제거가 필요함

# %%
for genre, data in genre_tokens_dict.items():
    text_str = ' '.join(data['tokens'])
    top_words = extract_lsa_top_words(text_str, topn=15)
    word_set = [word for word, _ in top_words]
    
    # 기존 dict에 'lsa_top_words' 항목 추가
    genre_tokens_dict[genre]['lsa_top_words'] = word_set
# Out:
# TF-IDF 행렬의 크기: (1, 4698)
# 추출된 topic 수: 1
# Top 15 words in Topic 1:
# 위해: 0.30559
# 자신: 0.30242
# 시작: 0.26601
# 지구: 0.23750
# 사람: 0.22642
# 인간: 0.17417
# 인류: 0.15992
# 그녀: 0.13459
# 미래: 0.13300
# 세계: 0.13142
# 모든: 0.12034
# 로봇: 0.10134
# 우주: 0.10134
# 박사: 0.09975
# 존재: 0.09817
# TF-IDF 행렬의 크기: (1, 2470)
# 추출된 topic 수: 1
# Top 15 words in Topic 1:
# 엄마: 0.27110
# 영화제: 0.24055
# 아빠: 0.23673
# 자신: 0.23292
# 가족: 0.23292
# 위해: 0.21001
# 친구: 0.18328
# 아버지: 0.17946
# 시작: 0.17564
# 그녀: 0.17182
# 아들: 0.14891
# 마을: 0.14510
# 국제: 0.14510
# 사람: 0.12219
# 아이: 0.12219
# TF-IDF 행렬의 크기: (1, 2229)
# 추출된 topic 수: 1
# Top 15 words in Topic 1:
# 사랑: 0.39578
# 자신: 0.24356
# 오페라: 0.23595
# 그녀: 0.20550
# 위해: 0.16364
# 공연: 0.15603
# 실황: 0.15222
# 왕자: 0.11797
# 토스카: 0.11797
# 시작: 0.10656
# 도시: 0.10656
# 사람: 0.10275
# 무대: 0.10275
# 카바: 0.10275
# 백작: 0.09895
# TF-IDF 행렬의 크기: (1, 7761)
# 추출된 topic 수: 1
# Top 15 words in Topic 1:
# 시작: 0.27991
# 위해: 0.26220
# 사람: 0.26042
# 자신: 0.25216
# 친구: 0.24212
# 그녀: 0.24094
# 사건: 0.19428
# 공포: 0.17125
# 발견: 0.16003
# 죽음: 0.14291
# 마을: 0.12696
# 남자: 0.10393
# 가족: 0.10216
# 영화: 0.09567
# 하나: 0.09094
# TF-IDF 행렬의 크기: (1, 8036)
# 추출된 topic 수: 1
# Top 15 words in Topic 1:
# 영화제: 0.54690
# 국제: 0.42392
# 서울: 0.33354
# 단편: 0.27578
# 자신: 0.15699
# 영화: 0.15233
# 사람: 0.14581
# 이야기: 0.13044
# 그녀: 0.12717
# 남자: 0.10901
# 위해: 0.10481
# 시작: 0.09177
# 사랑: 0.09084
# 여자: 0.07500
# 대한: 0.07221
# TF-IDF 행렬의 크기: (1, 16162)
# 추출된 topic 수: 1
# Top 15 words in Topic 1:
# 영화제: 0.37173
# 영화: 0.29426
# 국제: 0.25323
# 사람: 0.22012
# 다큐멘터리: 0.19243
# 이야기: 0.18326
# 대한: 0.17514
# 자신: 0.16577
# 감독: 0.15640
# 위해: 0.15390
# 시작: 0.14453
# 우리: 0.13953
# 다큐: 0.13599
# 세계: 0.12870
# 서울: 0.12849
# TF-IDF 행렬의 크기: (1, 24040)
# 추출된 topic 수: 1
# Top 15 words in Topic 1:
# 자신: 0.31023
# 영화제: 0.30425
# 그녀: 0.29164
# 사람: 0.21404
# 사랑: 0.21264
# 위해: 0.19882
# 영화: 0.19088
# 시작: 0.19060
# 국제: 0.15745
# 남자: 0.15334
# 친구: 0.14185
# 이야기: 0.12682
# 아버지: 0.11421
# 엄마: 0.11253
# 가족: 0.10898
# TF-IDF 행렬의 크기: (1, 10744)
# 추출된 topic 수: 1
# Top 15 words in Topic 1:
# 그녀: 0.50359
# 사랑: 0.32722
# 자신: 0.26677
# 시작: 0.22268
# 남자: 0.21297
# 남편: 0.21020
# 사람: 0.17276
# 여자: 0.17165
# 친구: 0.15751
# 위해: 0.15169
# 마음: 0.13976
# 결혼: 0.10565
# 섹스: 0.10538
# 서로: 0.10510
# 아내: 0.10122
# TF-IDF 행렬의 크기: (1, 1397)
# 추출된 topic 수: 1
# Top 15 words in Topic 1:
# 사랑: 0.28825
# 그녀: 0.25434
# 뮤지컬: 0.22890
# 음악: 0.22043
# 영화: 0.20347
# 자신: 0.20347
# 영화제: 0.18651
# 시작: 0.14412
# 위해: 0.13565
# 충무로: 0.12717
# 최고: 0.11869
# 사람: 0.11021
# 모차르트: 0.10174
# 도시: 0.09326
# 공연: 0.09326
# TF-IDF 행렬의 크기: (1, 3745)
# 추출된 topic 수: 1
# Top 15 words in Topic 1:
# 사건: 0.37015
# 그녀: 0.31986
# 시작: 0.27761
# 자신: 0.25146
# 위해: 0.19111
# 사람: 0.17099
# 발견: 0.13277
# 죽음: 0.12473
# 진실: 0.11668
# 친구: 0.11265
# 사고: 0.11265
# 살인: 0.10863
# 기억: 0.10662
# 아내: 0.10461
# 남자: 0.10058
# TF-IDF 행렬의 크기: (1, 6004)
# 추출된 topic 수: 1
# Top 15 words in Topic 1:
# 사건: 0.33321
# 위해: 0.28287
# 자신: 0.28047
# 시작: 0.24691
# 경찰: 0.23852
# 그녀: 0.18938
# 살인: 0.15222
# 사람: 0.14982
# 조직: 0.14862
# 범죄: 0.13184
# 남자: 0.11267
# 마약: 0.11147
# 모든: 0.10667
# 발견: 0.10188
# 살해: 0.09948
# TF-IDF 행렬의 크기: (1, 1416)
# 추출된 topic 수: 1
# Top 15 words in Topic 1:
# 조선: 0.37831
# 위해: 0.28977
# 시작: 0.23342
# 사랑: 0.21733
# 자신: 0.20928
# 그녀: 0.16903
# 운명: 0.14488
# 최고: 0.14488
# 사람: 0.14488
# 전쟁: 0.12879
# 권력: 0.12879
# 황제: 0.12879
# 사건: 0.10464
# 마음: 0.08854
# 역사: 0.08854
# TF-IDF 행렬의 크기: (1, 455)
# 추출된 topic 수: 1
# Top 15 words in Topic 1:
# 서부: 0.29553
# 위해: 0.27280
# 보안관: 0.22733
# 마을: 0.22733
# 자신: 0.20460
# 헨리: 0.18187
# 아이: 0.18187
# 카우보이: 0.15913
# 시작: 0.15913
# 복수: 0.11367
# 아내: 0.11367
# 분노: 0.11367
# 가족: 0.11367
# 사람: 0.11367
# 사냥: 0.09093
# TF-IDF 행렬의 크기: (1, 5045)
# 추출된 topic 수: 1
# Top 15 words in Topic 1:
# 그녀: 0.53790
# 남편: 0.35606
# 자신: 0.25999
# 관계: 0.18020
# 남자: 0.16772
# 영화: 0.16338
# 위해: 0.16066
# 시작: 0.14547
# 섹스: 0.13352
# 마사지: 0.12755
# 여자: 0.12158
# 정사: 0.11670
# 마음: 0.10964
# 사랑: 0.10150
# 아내: 0.09444
# TF-IDF 행렬의 크기: (1, 6979)
# 추출된 topic 수: 1
# Top 15 words in Topic 1:
# 자신: 0.34656
# 그녀: 0.30952
# 사건: 0.29099
# 시작: 0.27555
# 위해: 0.25163
# 사람: 0.22615
# 살인: 0.17907
# 남자: 0.16209
# 발견: 0.12195
# 아내: 0.11578
# 친구: 0.10960
# 경찰: 0.10111
# 모든: 0.09725
# 사실: 0.09185
# 가족: 0.08954
# TF-IDF 행렬의 크기: (1, 12844)
# 추출된 topic 수: 1
# Top 15 words in Topic 1:
# 애니메이션: 0.38119
# 국제: 0.36798
# 영화제: 0.33435
# 친구: 0.23095
# 위해: 0.19259
# 자신: 0.18287
# 시작: 0.16219
# 사람: 0.16070
# 이야기: 0.12906
# 서울: 0.12607
# 아이: 0.12382
# 마을: 0.11585
# 페스티벌: 0.11535
# 세계: 0.10788
# 소녀: 0.10663
# TF-IDF 행렬의 크기: (1, 12925)
# 추출된 topic 수: 1
# Top 15 words in Topic 1:
# 위해: 0.39637
# 자신: 0.32732
# 시작: 0.26030
# 조직: 0.18346
# 사건: 0.18211
# 사람: 0.15604
# 그녀: 0.15232
# 경찰: 0.13675
# 전쟁: 0.10189
# 친구: 0.09850
# 모든: 0.09816
# 목숨: 0.09545
# 사실: 0.09444
# 세계: 0.08868
# 가족: 0.08835
# TF-IDF 행렬의 크기: (1, 3088)
# 추출된 topic 수: 1
# Top 15 words in Topic 1:
# 위해: 0.35558
# 자신: 0.22030
# 시작: 0.17779
# 친구: 0.17006
# 마을: 0.16619
# 아버지: 0.14300
# 아이: 0.13914
# 사람: 0.13914
# 영화: 0.13527
# 세계: 0.13141
# 여행: 0.12754
# 세상: 0.12368
# 가족: 0.11981
# 대한: 0.10822
# 모험: 0.10822
# TF-IDF 행렬의 크기: (1, 2635)
# 추출된 topic 수: 1
# Top 15 words in Topic 1:
# 전쟁: 0.33299
# 위해: 0.27009
# 전투: 0.24049
# 시작: 0.23309
# 작전: 0.22199
# 독일군: 0.18869
# 부대: 0.18499
# 독일: 0.15169
# 자신: 0.12210
# 사람: 0.11840
# 공격: 0.11100
# 임무: 0.10730
# 연합군: 0.09250
# 병사: 0.09250
# 미국: 0.09250
# TF-IDF 행렬의 크기: (1, 13766)
# 추출된 topic 수: 1
# Top 15 words in Topic 1:
# 그녀: 0.29591
# 자신: 0.29477
# 시작: 0.25802
# 위해: 0.25380
# 사랑: 0.22854
# 사람: 0.19830
# 친구: 0.19638
# 영화: 0.17954
# 남자: 0.17380
# 여자: 0.13284
# 영화제: 0.12250
# 가족: 0.11561
# 과연: 0.10987
# 마을: 0.10298
# 사건: 0.09302
# TF-IDF 행렬의 크기: (1, 3174)
# 추출된 topic 수: 1
# Top 15 words in Topic 1:
# 자신: 0.32088
# 그녀: 0.29913
# 시작: 0.27737
# 위해: 0.24746
# 사람: 0.21211
# 사랑: 0.19851
# 영화제: 0.15228
# 이야기: 0.12509
# 영화: 0.12237
# 소녀: 0.11421
# 남자: 0.11421
# 인간: 0.11149
# 세상: 0.10333
# 마을: 0.10061
# 세계: 0.10061

# %%
lsa_attribute = []
lsa_attribute = {g: genre_tokens_dict[g]['lsa_top_words'] for g in genre_name}

matrix_lsa = compute_weat_matrix(
    genre_names=genre_name,
    attribute_sets=lsa_attribute, # LSA 추출한 단어들
    target_art=art_attributes_set,
    target_gen=gen_attributes_set,
    model=model_all
)
# Out:
# 예술영화 vs 상업영화 | SF vs 가족: WEAT score = 0.0235
# 예술영화 vs 상업영화 | SF vs 공연: WEAT score = 0.4216
# 예술영화 vs 상업영화 | SF vs 공포(호러): WEAT score = -0.4925
# 예술영화 vs 상업영화 | SF vs 기타: WEAT score = 0.5989
# 예술영화 vs 상업영화 | SF vs 다큐멘터리: WEAT score = 0.4348
# 예술영화 vs 상업영화 | SF vs 드라마: WEAT score = 0.2745
# 예술영화 vs 상업영화 | SF vs 멜로로맨스: WEAT score = -0.0404
# 예술영화 vs 상업영화 | SF vs 뮤지컬: WEAT score = 0.4960
# 예술영화 vs 상업영화 | SF vs 미스터리: WEAT score = -0.4382
# 예술영화 vs 상업영화 | SF vs 범죄: WEAT score = -0.3097
# 예술영화 vs 상업영화 | SF vs 사극: WEAT score = 0.0303
# 예술영화 vs 상업영화 | SF vs 서부극(웨스턴): WEAT score = -0.2325
# 예술영화 vs 상업영화 | SF vs 성인물(에로): WEAT score = 0.1076
# 예술영화 vs 상업영화 | SF vs 스릴러: WEAT score = -0.3616
# 예술영화 vs 상업영화 | SF vs 애니메이션: WEAT score = 0.4722
# 예술영화 vs 상업영화 | SF vs 액션: WEAT score = -0.5102
# 예술영화 vs 상업영화 | SF vs 어드벤처: WEAT score = -0.3985
# 예술영화 vs 상업영화 | SF vs 전쟁: WEAT score = 0.0551
# 예술영화 vs 상업영화 | SF vs 코미디: WEAT score = -0.0391
# 예술영화 vs 상업영화 | SF vs 판타지: WEAT score = 0.1206
# 예술영화 vs 상업영화 | 가족 vs 공연: WEAT score = 0.4661
# 예술영화 vs 상업영화 | 가족 vs 공포(호러): WEAT score = -0.5312
# 예술영화 vs 상업영화 | 가족 vs 기타: WEAT score = 0.6122
# 예술영화 vs 상업영화 | 가족 vs 다큐멘터리: WEAT score = 0.3971
# 예술영화 vs 상업영화 | 가족 vs 드라마: WEAT score = 0.3549
# 예술영화 vs 상업영화 | 가족 vs 멜로로맨스: WEAT score = -0.0618
# 예술영화 vs 상업영화 | 가족 vs 뮤지컬: WEAT score = 0.5145
# 예술영화 vs 상업영화 | 가족 vs 미스터리: WEAT score = -0.4712
# 예술영화 vs 상업영화 | 가족 vs 범죄: WEAT score = -0.3033
# 예술영화 vs 상업영화 | 가족 vs 사극: WEAT score = -0.0012
# 예술영화 vs 상업영화 | 가족 vs 서부극(웨스턴): WEAT score = -0.2978
# 예술영화 vs 상업영화 | 가족 vs 성인물(에로): WEAT score = 0.1107
# 예술영화 vs 상업영화 | 가족 vs 스릴러: WEAT score = -0.3987
# 예술영화 vs 상업영화 | 가족 vs 애니메이션: WEAT score = 0.5204
# 예술영화 vs 상업영화 | 가족 vs 액션: WEAT score = -0.5022
# 예술영화 vs 상업영화 | 가족 vs 어드벤처: WEAT score = -0.4851
# 예술영화 vs 상업영화 | 가족 vs 전쟁: WEAT score = 0.0174
# 예술영화 vs 상업영화 | 가족 vs 코미디: WEAT score = -0.0718
# 예술영화 vs 상업영화 | 가족 vs 판타지: WEAT score = 0.1004
# 예술영화 vs 상업영화 | 공연 vs 공포(호러): WEAT score = -0.6623
# 예술영화 vs 상업영화 | 공연 vs 기타: WEAT score = 0.4058
# 예술영화 vs 상업영화 | 공연 vs 다큐멘터리: WEAT score = 0.1955
# 예술영화 vs 상업영화 | 공연 vs 드라마: WEAT score = -0.1538
# 예술영화 vs 상업영화 | 공연 vs 멜로로맨스: WEAT score = -0.3207
# 예술영화 vs 상업영화 | 공연 vs 뮤지컬: WEAT score = 0.3396
# 예술영화 vs 상업영화 | 공연 vs 미스터리: WEAT score = -0.6436
# 예술영화 vs 상업영화 | 공연 vs 범죄: WEAT score = -0.5192
# 예술영화 vs 상업영화 | 공연 vs 사극: WEAT score = -0.5833
# 예술영화 vs 상업영화 | 공연 vs 서부극(웨스턴): WEAT score = -0.5674
# 예술영화 vs 상업영화 | 공연 vs 성인물(에로): WEAT score = -0.1836
# 예술영화 vs 상업영화 | 공연 vs 스릴러: WEAT score = -0.5928
# 예술영화 vs 상업영화 | 공연 vs 애니메이션: WEAT score = 0.1660
# 예술영화 vs 상업영화 | 공연 vs 액션: WEAT score = -0.6852
# 예술영화 vs 상업영화 | 공연 vs 어드벤처: WEAT score = -0.6523
# 예술영화 vs 상업영화 | 공연 vs 전쟁: WEAT score = -0.2953
# 예술영화 vs 상업영화 | 공연 vs 코미디: WEAT score = -0.4813
# 예술영화 vs 상업영화 | 공연 vs 판타지: WEAT score = -0.3367
# 예술영화 vs 상업영화 | 공포(호러) vs 기타: WEAT score = 0.7175
# 예술영화 vs 상업영화 | 공포(호러) vs 다큐멘터리: WEAT score = 0.5665
# 예술영화 vs 상업영화 | 공포(호러) vs 드라마: WEAT score = 0.7151
# 예술영화 vs 상업영화 | 공포(호러) vs 멜로로맨스: WEAT score = 0.3478
# 예술영화 vs 상업영화 | 공포(호러) vs 뮤지컬: WEAT score = 0.6357
# 예술영화 vs 상업영화 | 공포(호러) vs 미스터리: WEAT score = -0.1413
# 예술영화 vs 상업영화 | 공포(호러) vs 범죄: WEAT score = 0.2118
# 예술영화 vs 상업영화 | 공포(호러) vs 사극: WEAT score = 0.6067
# 예술영화 vs 상업영화 | 공포(호러) vs 서부극(웨스턴): WEAT score = 0.4583
# 예술영화 vs 상업영화 | 공포(호러) vs 성인물(에로): WEAT score = 0.5041
# 예술영화 vs 상업영화 | 공포(호러) vs 스릴러: WEAT score = 0.1258
# 예술영화 vs 상업영화 | 공포(호러) vs 애니메이션: WEAT score = 0.6422
# 예술영화 vs 상업영화 | 공포(호러) vs 액션: WEAT score = 0.0990
# 예술영화 vs 상업영화 | 공포(호러) vs 어드벤처: WEAT score = 0.2428
# 예술영화 vs 상업영화 | 공포(호러) vs 전쟁: WEAT score = 0.4554
# 예술영화 vs 상업영화 | 공포(호러) vs 코미디: WEAT score = 0.6625
# 예술영화 vs 상업영화 | 공포(호러) vs 판타지: WEAT score = 0.5739
# 예술영화 vs 상업영화 | 기타 vs 다큐멘터리: WEAT score = -0.2213
# 예술영화 vs 상업영화 | 기타 vs 드라마: WEAT score = -0.5444
# 예술영화 vs 상업영화 | 기타 vs 멜로로맨스: WEAT score = -0.4159
# 예술영화 vs 상업영화 | 기타 vs 뮤지컬: WEAT score = -0.1086
# 예술영화 vs 상업영화 | 기타 vs 미스터리: WEAT score = -0.6780
# 예술영화 vs 상업영화 | 기타 vs 범죄: WEAT score = -0.6053
# 예술영화 vs 상업영화 | 기타 vs 사극: WEAT score = -0.5726
# 예술영화 vs 상업영화 | 기타 vs 서부극(웨스턴): WEAT score = -0.6461
# 예술영화 vs 상업영화 | 기타 vs 성인물(에로): WEAT score = -0.3617
# 예술영화 vs 상업영화 | 기타 vs 스릴러: WEAT score = -0.6352
# 예술영화 vs 상업영화 | 기타 vs 애니메이션: WEAT score = -0.4621
# 예술영화 vs 상업영화 | 기타 vs 액션: WEAT score = -0.6943
# 예술영화 vs 상업영화 | 기타 vs 어드벤처: WEAT score = -0.7819
# 예술영화 vs 상업영화 | 기타 vs 전쟁: WEAT score = -0.5274
# 예술영화 vs 상업영화 | 기타 vs 코미디: WEAT score = -0.7107
# 예술영화 vs 상업영화 | 기타 vs 판타지: WEAT score = -0.7880
# 예술영화 vs 상업영화 | 다큐멘터리 vs 드라마: WEAT score = -0.2772
# 예술영화 vs 상업영화 | 다큐멘터리 vs 멜로로맨스: WEAT score = -0.2861
# 예술영화 vs 상업영화 | 다큐멘터리 vs 뮤지컬: WEAT score = 0.1407
# 예술영화 vs 상업영화 | 다큐멘터리 vs 미스터리: WEAT score = -0.5411
# 예술영화 vs 상업영화 | 다큐멘터리 vs 범죄: WEAT score = -0.4717
# 예술영화 vs 상업영화 | 다큐멘터리 vs 사극: WEAT score = -0.3831
# 예술영화 vs 상업영화 | 다큐멘터리 vs 서부극(웨스턴): WEAT score = -0.4681
# 예술영화 vs 상업영화 | 다큐멘터리 vs 성인물(에로): WEAT score = -0.2208
# 예술영화 vs 상업영화 | 다큐멘터리 vs 스릴러: WEAT score = -0.4905
# 예술영화 vs 상업영화 | 다큐멘터리 vs 애니메이션: WEAT score = -0.1133
# 예술영화 vs 상업영화 | 다큐멘터리 vs 액션: WEAT score = -0.5526
# 예술영화 vs 상업영화 | 다큐멘터리 vs 어드벤처: WEAT score = -0.6211
# 예술영화 vs 상업영화 | 다큐멘터리 vs 전쟁: WEAT score = -0.3892
# 예술영화 vs 상업영화 | 다큐멘터리 vs 코미디: WEAT score = -0.4681
# 예술영화 vs 상업영화 | 다큐멘터리 vs 판타지: WEAT score = -0.4925
# 예술영화 vs 상업영화 | 드라마 vs 멜로로맨스: WEAT score = -0.2857
# 예술영화 vs 상업영화 | 드라마 vs 뮤지컬: WEAT score = 0.4416
# 예술영화 vs 상업영화 | 드라마 vs 미스터리: WEAT score = -0.6788
# 예술영화 vs 상업영화 | 드라마 vs 범죄: WEAT score = -0.4741
# 예술영화 vs 상업영화 | 드라마 vs 사극: WEAT score = -0.3563
# 예술영화 vs 상업영화 | 드라마 vs 서부극(웨스턴): WEAT score = -0.4347
# 예술영화 vs 상업영화 | 드라마 vs 성인물(에로): WEAT score = -0.1079
# 예술영화 vs 상업영화 | 드라마 vs 스릴러: WEAT score = -0.6002
# 예술영화 vs 상업영화 | 드라마 vs 애니메이션: WEAT score = 0.2909
# 예술영화 vs 상업영화 | 드라마 vs 액션: WEAT score = -0.6280
# 예술영화 vs 상업영화 | 드라마 vs 어드벤처: WEAT score = -0.7187
# 예술영화 vs 상업영화 | 드라마 vs 전쟁: WEAT score = -0.1796
# 예술영화 vs 상업영화 | 드라마 vs 코미디: WEAT score = -0.6640
# 예술영화 vs 상업영화 | 드라마 vs 판타지: WEAT score = -0.3688
# 예술영화 vs 상업영화 | 멜로로맨스 vs 뮤지컬: WEAT score = 0.3801
# 예술영화 vs 상업영화 | 멜로로맨스 vs 미스터리: WEAT score = -0.4210
# 예술영화 vs 상업영화 | 멜로로맨스 vs 범죄: WEAT score = -0.1988
# 예술영화 vs 상업영화 | 멜로로맨스 vs 사극: WEAT score = 0.0734
# 예술영화 vs 상업영화 | 멜로로맨스 vs 서부극(웨스턴): WEAT score = -0.0530
# 예술영화 vs 상업영화 | 멜로로맨스 vs 성인물(에로): WEAT score = 0.4201
# 예술영화 vs 상업영화 | 멜로로맨스 vs 스릴러: WEAT score = -0.3295
# 예술영화 vs 상업영화 | 멜로로맨스 vs 애니메이션: WEAT score = 0.2968
# 예술영화 vs 상업영화 | 멜로로맨스 vs 액션: WEAT score = -0.2824
# 예술영화 vs 상업영화 | 멜로로맨스 vs 어드벤처: WEAT score = -0.1705
# 예술영화 vs 상업영화 | 멜로로맨스 vs 전쟁: WEAT score = 0.0511
# 예술영화 vs 상업영화 | 멜로로맨스 vs 코미디: WEAT score = 0.0254
# 예술영화 vs 상업영화 | 멜로로맨스 vs 판타지: WEAT score = 0.1122
# 예술영화 vs 상업영화 | 뮤지컬 vs 미스터리: WEAT score = -0.6202
# 예술영화 vs 상업영화 | 뮤지컬 vs 범죄: WEAT score = -0.5351
# 예술영화 vs 상업영화 | 뮤지컬 vs 사극: WEAT score = -0.4927
# 예술영화 vs 상업영화 | 뮤지컬 vs 서부극(웨스턴): WEAT score = -0.5366
# 예술영화 vs 상업영화 | 뮤지컬 vs 성인물(에로): WEAT score = -0.3264
# 예술영화 vs 상업영화 | 뮤지컬 vs 스릴러: WEAT score = -0.5713
# 예술영화 vs 상업영화 | 뮤지컬 vs 애니메이션: WEAT score = -0.2251
# 예술영화 vs 상업영화 | 뮤지컬 vs 액션: WEAT score = -0.6201
# 예술영화 vs 상업영화 | 뮤지컬 vs 어드벤처: WEAT score = -0.6839
# 예술영화 vs 상업영화 | 뮤지컬 vs 전쟁: WEAT score = -0.4204
# 예술영화 vs 상업영화 | 뮤지컬 vs 코미디: WEAT score = -0.5932
# 예술영화 vs 상업영화 | 뮤지컬 vs 판타지: WEAT score = -0.6376
# 예술영화 vs 상업영화 | 미스터리 vs 범죄: WEAT score = 0.3307
# 예술영화 vs 상업영화 | 미스터리 vs 사극: WEAT score = 0.5618
# 예술영화 vs 상업영화 | 미스터리 vs 서부극(웨스턴): WEAT score = 0.3783
# 예술영화 vs 상업영화 | 미스터리 vs 성인물(에로): WEAT score = 0.5863
# 예술영화 vs 상업영화 | 미스터리 vs 스릴러: WEAT score = 0.4627
# 예술영화 vs 상업영화 | 미스터리 vs 애니메이션: WEAT score = 0.5852
# 예술영화 vs 상업영화 | 미스터리 vs 액션: WEAT score = 0.1768
# 예술영화 vs 상업영화 | 미스터리 vs 어드벤처: WEAT score = 0.2267
# 예술영화 vs 상업영화 | 미스터리 vs 전쟁: WEAT score = 0.4114
# 예술영화 vs 상업영화 | 미스터리 vs 코미디: WEAT score = 0.5902
# 예술영화 vs 상업영화 | 미스터리 vs 판타지: WEAT score = 0.5212
# 예술영화 vs 상업영화 | 범죄 vs 사극: WEAT score = 0.3601
# 예술영화 vs 상업영화 | 범죄 vs 서부극(웨스턴): WEAT score = 0.2151
# 예술영화 vs 상업영화 | 범죄 vs 성인물(에로): WEAT score = 0.3589
# 예술영화 vs 상업영화 | 범죄 vs 스릴러: WEAT score = -0.1769
# 예술영화 vs 상업영화 | 범죄 vs 애니메이션: WEAT score = 0.5061
# 예술영화 vs 상업영화 | 범죄 vs 액션: WEAT score = -0.1936
# 예술영화 vs 상업영화 | 범죄 vs 어드벤처: WEAT score = 0.0422
# 예술영화 vs 상업영화 | 범죄 vs 전쟁: WEAT score = 0.3553
# 예술영화 vs 상업영화 | 범죄 vs 코미디: WEAT score = 0.3379
# 예술영화 vs 상업영화 | 범죄 vs 판타지: WEAT score = 0.3477
# 예술영화 vs 상업영화 | 사극 vs 서부극(웨스턴): WEAT score = -0.2589
# 예술영화 vs 상업영화 | 사극 vs 성인물(에로): WEAT score = 0.1414
# 예술영화 vs 상업영화 | 사극 vs 스릴러: WEAT score = -0.4681
# 예술영화 vs 상업영화 | 사극 vs 애니메이션: WEAT score = 0.4089
# 예술영화 vs 상업영화 | 사극 vs 액션: WEAT score = -0.6101
# 예술영화 vs 상업영화 | 사극 vs 어드벤처: WEAT score = -0.4470
# 예술영화 vs 상업영화 | 사극 vs 전쟁: WEAT score = 0.0191
# 예술영화 vs 상업영화 | 사극 vs 코미디: WEAT score = -0.0833
# 예술영화 vs 상업영화 | 사극 vs 판타지: WEAT score = 0.1102
# 예술영화 vs 상업영화 | 서부극(웨스턴) vs 성인물(에로): WEAT score = 0.2104
# 예술영화 vs 상업영화 | 서부극(웨스턴) vs 스릴러: WEAT score = -0.2954
# 예술영화 vs 상업영화 | 서부극(웨스턴) vs 애니메이션: WEAT score = 0.5751
# 예술영화 vs 상업영화 | 서부극(웨스턴) vs 액션: WEAT score = -0.4446
# 예술영화 vs 상업영화 | 서부극(웨스턴) vs 어드벤처: WEAT score = -0.2817
# 예술영화 vs 상업영화 | 서부극(웨스턴) vs 전쟁: WEAT score = 0.2594
# 예술영화 vs 상업영화 | 서부극(웨스턴) vs 코미디: WEAT score = 0.1466
# 예술영화 vs 상업영화 | 서부극(웨스턴) vs 판타지: WEAT score = 0.2760
# 예술영화 vs 상업영화 | 성인물(에로) vs 스릴러: WEAT score = -0.5049
# 예술영화 vs 상업영화 | 성인물(에로) vs 애니메이션: WEAT score = 0.2082
# 예술영화 vs 상업영화 | 성인물(에로) vs 액션: WEAT score = -0.4375
# 예술영화 vs 상업영화 | 성인물(에로) vs 어드벤처: WEAT score = -0.3307
# 예술영화 vs 상업영화 | 성인물(에로) vs 전쟁: WEAT score = -0.0691
# 예술영화 vs 상업영화 | 성인물(에로) vs 코미디: WEAT score = -0.1885
# 예술영화 vs 상업영화 | 성인물(에로) vs 판타지: WEAT score = -0.0534
# 예술영화 vs 상업영화 | 스릴러 vs 애니메이션: WEAT score = 0.5398
# 예술영화 vs 상업영화 | 스릴러 vs 액션: WEAT score = -0.0240
# 예술영화 vs 상업영화 | 스릴러 vs 어드벤처: WEAT score = 0.1194
# 예술영화 vs 상업영화 | 스릴러 vs 전쟁: WEAT score = 0.3559
# 예술영화 vs 상업영화 | 스릴러 vs 코미디: WEAT score = 0.4723
# 예술영화 vs 상업영화 | 스릴러 vs 판타지: WEAT score = 0.4302
# 예술영화 vs 상업영화 | 애니메이션 vs 액션: WEAT score = -0.6139
# 예술영화 vs 상업영화 | 애니메이션 vs 어드벤처: WEAT score = -0.7281
# 예술영화 vs 상업영화 | 애니메이션 vs 전쟁: WEAT score = -0.4251
# 예술영화 vs 상업영화 | 애니메이션 vs 코미디: WEAT score = -0.5344
# 예술영화 vs 상업영화 | 애니메이션 vs 판타지: WEAT score = -0.5388
# 예술영화 vs 상업영화 | 액션 vs 어드벤처: WEAT score = 0.1653
# 예술영화 vs 상업영화 | 액션 vs 전쟁: WEAT score = 0.5204
# 예술영화 vs 상업영화 | 액션 vs 코미디: WEAT score = 0.5192
# 예술영화 vs 상업영화 | 액션 vs 판타지: WEAT score = 0.4905
# 예술영화 vs 상업영화 | 어드벤처 vs 전쟁: WEAT score = 0.3292
# 예술영화 vs 상업영화 | 어드벤처 vs 코미디: WEAT score = 0.4621
# 예술영화 vs 상업영화 | 어드벤처 vs 판타지: WEAT score = 0.6369
# 예술영화 vs 상업영화 | 전쟁 vs 코미디: WEAT score = -0.0641
# 예술영화 vs 상업영화 | 전쟁 vs 판타지: WEAT score = 0.0550
# 예술영화 vs 상업영화 | 코미디 vs 판타지: WEAT score = 0.3025

# %%
np.random.seed(0)

# 한글 지원 폰트
sns.set(font='NanumGothic')

# 마이너스 부호 
plt.rcParams['axes.unicode_minus'] = False
plt.figure(figsize=(12, 10))

ax = sns.heatmap(matrix_lsa, xticklabels=genre_name, yticklabels=genre_name, annot=True,  cmap='RdYlGn_r')


plt.title('장르 간 WEAT Score (LSA 기반)', fontsize=18)
plt.tight_layout()
plt.show()

plt.savefig('weat_score_heatmap_lsa.png', dpi=100, bbox_inches='tight')

# %% [markdown]
# # 회고

# %% [markdown]
# 1. 중심벡터 유사도 방식에서, 왜 중심 근처에 의미 없는 단어가 모일까?
#    1) 중립적인 단어일수록 중심에 가까움
#        - 자주 등장하지만 특정 맥락에서 특이하지 않은 단어들(예: "사람", "장면", "이야기", "그", "것")은 다양한 문맥에서 사용되므로,
#        - 여러 방향의 벡터가 평균되면서 중심 근처로 이동
#    2) 벡터 평균 자체가 ‘애매한 뜻’을 가짐
#        - Word2Vec은 학습 과정에서 자주 등장하는 단어(예: "하다", "되다", "있다")를 벡터 공간의 중심 근처로 배치함
#
# 2. 중심벡터 유사도 방식 사용시,  개선점
#    1) TF-IDF 필터링 (stop-words 처리)를 하는 것이 좋겠음
#    2) 중심 벡터가 아닌 클러스터 중심 사용하는 방법

# %% [markdown]
# 3. LSA
#     - LSA로 잠재 토픽 기반 추출시,  TF-IDF와 비슷함
#     - target들 간에 중복 제거가 필요함

# %% [markdown]
# 4. heatmap으로 봤을때, 내가 생각했던 점수와는 다르게 나왔는데 (공포(호러)가 예술영화쪽으로 나옴, 다큐멘터리가 상업영화쪽으로 나옴)
