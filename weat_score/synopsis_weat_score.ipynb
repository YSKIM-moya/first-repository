# %% [markdown]
# # 임베딩 내 편향성 알아보기

# %%
import os
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
import numpy as np
from numpy import dot
from numpy.linalg import norm

# %%
def cos_sim(i, j):
    return dot(i, j.T)/(norm(i)*norm(j))

# s(w,A,B)는 개별 단어 w가 개념축 A-B에 대해 가지는 편향성을 계산한 값
# -2 ~ 2의 값
def s(w, A, B):
    c_a = cos_sim(w, A)
    c_b = cos_sim(w, B)
    mean_A = np.mean(c_a, axis=-1)
    mean_B = np.mean(c_b, axis=-1)
    return mean_A - mean_B #, c_a, c_b

# s(X,A,B)평균 - s(Y,A,B)평균을 전체 표준편차로 나눈 값
def weat_score(X, Y, A, B):
    
    s_X = s(X, A, B)
    s_Y = s(Y, A, B)

    mean_X = np.mean(s_X)
    mean_Y = np.mean(s_Y)
    
    std_dev = np.std(np.concatenate([s_X, s_Y], axis=0))
    
    return  (mean_X-mean_Y)/std_dev

# %%
from gensim.models import Word2Vec

def get_representative_words(token_list, vector_size=100, window=5, min_count=3, sg=0, topn=15):
    """
    Word2Vec을 학습하고 중심 벡터에 가장 가까운 단어 topn개를 반환합니다.
    
    Args:
        token_list (List[List[str]]): 문장 단위 토큰 리스트
        vector_size (int): 임베딩 차원 수
        window (int): 윈도우 크기
        min_count (int): 최소 단어 등장 빈도
        sg (int): 0=CBOW, 1=Skip-gram
        topn (int): 반환할 대표 단어 수
        
    Returns:
        List[str]: 중심 벡터에 가장 가까운 대표 단어 리스트
    """
    
    # Word2Vec 모델 학습
    model = Word2Vec(sentences=token_list, vector_size=vector_size, window=window, min_count=min_count, sg=sg)

    # 중심 벡터 계산
    vector_mean = np.mean([model.wv[word] for word in model.wv.index_to_key], axis=0)

    # 중심 벡터에 가장 가까운 단어 topn개 추출
    representative_words = model.wv.similar_by_vector(vector_mean, topn=topn)
    
    return [word for word, _ in representative_words]

# %% [markdown]
# ## 1. 명사만 추출 및 embedding model 만들기

# %%
from konlpy.tag import Okt

okt = Okt()

# %%
#  형태소 분석기를 이용하여 품사가 명사인 경우, 해당 단어를 추출하기


def read_token(file_name):
    result = []
    with open(os.getenv('HOME')+'/aiffel/weat/'+file_name, 'r') as fread: 
        print(file_name, '파일을 읽고 있습니다.')
        while True:
            line = fread.readline() 
            if not line: break 
            
            tokenlist = okt.pos(line, stem=True, norm=True) # 어간 추출, 표준화
            for word in tokenlist:
                if word[1] in ["Noun"]:      #, "Adjective", "Verb"]:
                    result.append((word[0])) # 명사일 때만 tokenized 에 저장하게 됩니다. 
                    
    return result

def read_token_to_str(file_name):
    tokens = read_token(file_name)
    return ' '.join(tokens)

# %% [markdown]
# ### 전체 파일 ###

# %%
# 약 15분정도 걸립니다.

tokenized = []
with open(os.getenv('HOME')+'/aiffel/weat/synopsis.txt', 'r') as file:
    while True:
        line = file.readline()
        if not line: break
        words = okt.pos(line, stem=True, norm=True) # 어간 추출, 표준화
        # [('오늘', 'Noun'), ('은', 'Josa'), ('날씨', 'Noun'), ('가', 'Josa'), ('정말', 'Adverb'), ('좋다', 'Adjective'), ('!', 'Punctuation')]
        
        res = []
        for w in words:
            if w[1] in ["Noun"]:      # "Adjective", "Verb" 등을 포함할 수도 있습니다.
                res.append(w[0])    # 명사일 때만 tokenized 에 저장하게 됩니다. 
        tokenized.append(res)

print(len(tokenized))
# Out:
# 71156

# %%
# 전체 문서 파일에 대해서 word embedding 만들기

from gensim.models import Word2Vec

# 1. 토큰 추출하기
all_txt = 'synopsis.txt'
# tokenized = read_token(all_txt)        
print(f'{all_txt}의 토큰: ', len(tokenized))

# 2. 토큰으로 embedding model 만들기
model_all = Word2Vec(tokenized, vector_size=100, window=5, min_count=3, sg=0)
# Out:
# synopsis.txt의 토큰:  71156

# %%
print('Word2Vec 단어 수:', len(model_all.wv))
print('상위 20개 단어:', model_all.wv.index_to_key[:20])
# Out:
# Word2Vec 단어 수: 24320
# 상위 20개 단어: ['그', '것', '이', '자신', '그녀', '수', '영화제', '제', '위해', '시작', '사람', '날', '국제', '사랑', '영화', '친구', '집', '남자', '알', '속']

# %%
model_all.wv.most_similar(positive=['사랑'])
# Out:
# [('만남', 0.6899369955062866),
#  ('이별', 0.6877090334892273),
#  ('첫사랑', 0.6872538924217224),
#  ('행복', 0.6846103072166443),
#  ('정일', 0.6842008233070374),
#  ('연애', 0.6823093891143799),
#  ('만인', 0.6810586452484131),
#  ('열정', 0.6636145114898682),
#  ('고백', 0.658753514289856),
#  ('운명', 0.6568127870559692)]

# %%
model_all.wv.most_similar(positive=['영화'])
# Out:
# [('작품', 0.8914897441864014),
#  ('다큐멘터리', 0.8577653169631958),
#  ('드라마', 0.8312057256698608),
#  ('영화로', 0.8121709227561951),
#  ('형식', 0.7832354307174683),
#  ('코미디', 0.7811157703399658),
#  ('주제', 0.7795397639274597),
#  ('스토리', 0.771876871585846),
#  ('버자이너', 0.7697139382362366),
#  ('감동', 0.7692899107933044)]

# %% [markdown]
# ### target 파일 (art, gen) ###

# %%
art_txt = 'synopsis_art.txt'
gen_txt = 'synopsis_gen.txt'

# 2개의 파일을 처리하는데 10분 가량 걸립니다. 
# 여기서 읽어들인 토큰들은 "중심벡터유사도방식" 사용할 예정임. 
art_tokens = read_token(art_txt) # 리스트 형태로 반환
gen_tokens = read_token(gen_txt)
art_str = ' '.join(art_tokens)   # 리스트를 문자열로 변환
gen_str = ' '.join(gen_tokens)

print(f'{art_txt}의 토큰: ', len(art_tokens))
print(f'{gen_txt}의 토큰: ', len(gen_tokens))
# Out:
# synopsis_art.txt 파일을 읽고 있습니다.
# synopsis_gen.txt 파일을 읽고 있습니다.
# synopsis_art.txt의 토큰:  208471
# synopsis_gen.txt의 토큰:  1008358

# %% [markdown]
# ### 모든 장르 파일 ###

# %%
#4. 모든 장르의 대표 단어를 추출 
genre_txt = ['synopsis_SF.txt', 'synopsis_family.txt', 'synopsis_show.txt', 'synopsis_horror.txt', 'synopsis_etc.txt', 
             'synopsis_documentary.txt', 'synopsis_drama.txt', 'synopsis_romance.txt', 'synopsis_musical.txt', 
             'synopsis_mystery.txt', 'synopsis_crime.txt', 'synopsis_historical.txt', 'synopsis_western.txt', 
             'synopsis_adult.txt', 'synopsis_thriller.txt', 'synopsis_animation.txt', 'synopsis_action.txt', 
             'synopsis_adventure.txt', 'synopsis_war.txt', 'synopsis_comedy.txt', 'synopsis_fantasy.txt']
genre_name = ['SF', '가족', '공연', '공포(호러)', '기타', '다큐멘터리', '드라마', '멜로로맨스', '뮤지컬', '미스터리', '범죄', '사극', '서부극(웨스턴)',
         '성인물(에로)', '스릴러', '애니메이션', '액션', '어드벤처', '전쟁', '코미디', '판타지']


# 1). 토큰 추출하기
genre_tokens_dict = {}
genre_all_str = []

for file_name, name in zip(genre_txt, genre_name):
    tokens = read_token(file_name)
    
    rep_words = get_representative_words(tokens)  # 중심단어 추출
    genre_tokens_dict[name] = {
        'tokens': tokens,
        'representative_words': rep_words
    }
      
    genre_all_str.append(' '.join(tokens))
    

    
# 2) 결과 확인
for genre, data in genre_tokens_dict.items():
    print(f'{genre} 장르의 토큰 수:', len(data['tokens']))
    print(f'  대표 단어: {data["representative_words"][:15]}')  # 일부만 출력

print('\n전체 통합 토큰 수:', len(genre_all_str))
# Out:
# synopsis_SF.txt 파일을 읽고 있습니다.
# synopsis_family.txt 파일을 읽고 있습니다.
# synopsis_show.txt 파일을 읽고 있습니다.
# synopsis_horror.txt 파일을 읽고 있습니다.
# synopsis_etc.txt 파일을 읽고 있습니다.
# synopsis_documentary.txt 파일을 읽고 있습니다.
# synopsis_drama.txt 파일을 읽고 있습니다.
# synopsis_romance.txt 파일을 읽고 있습니다.
# synopsis_musical.txt 파일을 읽고 있습니다.
# synopsis_mystery.txt 파일을 읽고 있습니다.
# synopsis_crime.txt 파일을 읽고 있습니다.
# synopsis_historical.txt 파일을 읽고 있습니다.
# synopsis_western.txt 파일을 읽고 있습니다.
# synopsis_adult.txt 파일을 읽고 있습니다.
# synopsis_thriller.txt 파일을 읽고 있습니다.
# synopsis_animation.txt 파일을 읽고 있습니다.
# synopsis_action.txt 파일을 읽고 있습니다.
# synopsis_adventure.txt 파일을 읽고 있습니다.
# synopsis_war.txt 파일을 읽고 있습니다.
# synopsis_comedy.txt 파일을 읽고 있습니다.
# synopsis_fantasy.txt 파일을 읽고 있습니다.
# SF 장르의 토큰 수: 21712
#   대표 단어: ['티', '오', '디', '코', '수', '턴', '브', '만', '노', '라', '분', '드', '에', '어', '트']
# 가족 장르의 토큰 수: 8006
#   대표 단어: ['스', '리', '이', '기', '마', '트', '가', '로', '드', '자', '사', '모', '인', '지', '아']
# 공연 장르의 토큰 수: 7984
#   대표 단어: ['스', '리', '르', '이', '마', '로', '트', '아', '레', '피', '지', '인', '라', '가', '드']
# 공포(호러) 장르의 토큰 수: 57802
#   대표 단어: ['던', '글', '셔', '칙', '궁', '딩', '채', '삭', '칠', '컨', '롱', '류', '겨', '싱', '낙']
# 기타 장르의 토큰 수: 49025
#   대표 단어: ['며', '링', '닥', '멜', '새', '느', '힘', '흐', '컨', '암', '돌', '패', '픽', '콩', '싸']
# 다큐멘터리 장르의 토큰 수: 156822
#   대표 단어: ['갬', '꿋', '끈', '솜', '땡', '팡', '쩍', '툭', '잎', '텃', '팟', '낌', '깜', '뜻', '훌']
# 드라마 장르의 토큰 수: 377566
#   대표 단어: ['훨', '짹', '쥔', '욜', '뿍', '떵', '텃', '꿋', '쭉', '쫄', '읊', '컥', '껀', '헹', '쪼']
# 멜로로맨스 장르의 토큰 수: 102083
#   대표 단어: ['훌', '룬', '쟈', '밖', '툰', '쿤', '꿍', '삐', '뜩', '웹', '틈', '꿋', '렁', '홧', '섬']
# 뮤지컬 장르의 토큰 수: 3442
#   대표 단어: ['이', '로', '리', '스', '메', '르', '니', '아', '프', '모', '지', '마', '인', '발', '전']
# 미스터리 장르의 토큰 수: 15726
#   대표 단어: ['스', '드', '오', '니', '로', '이', '트', '가', '수', '거', '유', '리', '라', '어', '레']
# 범죄 장르의 토큰 수: 29567
#   대표 단어: ['류', '저', '허', '투', '느', '애', '슨', '양', '워', '급', '코', '면', '송', '더', '즈']
# 사극 장르의 토큰 수: 3620
#   대표 단어: ['기', '전', '성', '이', '일', '도', '아', '명', '군', '트', '나', '각', '라', '정', '화']
# 서부극(웨스턴) 장르의 토큰 수: 925
#   대표 단어: ['나', '금', '결', '보', '탠', '소', '치', '때', '최', '이', '식', '타', '발', '착', '라']
# 성인물(에로) 장르의 토큰 수: 45227
#   대표 단어: ['션', '싱', '탈', '볼', '워', '슈', '농', '궁', '엉', '힘', '링', '양', '걸', '괴', '철']
# 스릴러 장르의 토큰 수: 43043
#   대표 단어: ['허', '킨', '런', '닥', '느', '월', '싱', '립', '급', '혈', '며', '홍', '핑', '슨', '함']
# 애니메이션 장르의 토큰 수: 121876
#   대표 단어: ['쭉', '싹', '빼', '땡', '똑', '퐁', '꽁', '낌', '꼼', '훌', '헝', '밭', '샘', '왓', '깍']
# 액션 장르의 토큰 수: 115561
#   대표 단어: ['쿵', '끈', '깜', '팬', '팽', '못', '캡', '솜', '앗', '값', '밖', '뜻', '톱', '컬', '솔']
# 어드벤처 장르의 토큰 수: 9687
#   대표 단어: ['스', '리', '이', '르', '지', '어', '레', '아', '드', '사', '라', '트', '로', '마', '자']
# 전쟁 장르의 토큰 수: 8462
#   대표 단어: ['스', '리', '르', '레', '가', '드', '아', '지', '소', '트', '니', '대', '전', '마', '인']
# 코미디 장르의 토큰 수: 107432
#   대표 단어: ['톡', '똘', '웰', '쭉', '몇', '땅', '멧', '꿍', '팽', '펭', '쿵', '냄', '샅', '삐', '챵']
# 판타지 장르의 토큰 수: 11994
#   대표 단어: ['스', '리', '드', '이', '가', '라', '아', '트', '지', '대', '기', '마', '어', '인', '로']
#
# 전체 통합 토큰 수: 21

# %% [markdown]
# ## 2. TF-IDF를 이용한 단어셋 추출 방법

# %%
# 3. TF-IDF로 해당 데이터를 가장 잘 표현하는 단어 셋 만들기
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform([art_str, gen_str])

print(X.shape)

m1 = X[0].tocoo()   # art를 TF-IDF로 표현한 sparse matrix를 가져옵니다. 
m2 = X[1].tocoo()   # gen을 TF-IDF로 표현한 sparse matrix를 가져옵니다. 

w1 = [[i, j] for i, j in zip(m1.col, m1.data)]
w2 = [[i, j] for i, j in zip(m2.col, m2.data)]

w1.sort(key=lambda x: x[1], reverse=True)   #art를 구성하는 단어들을 TF-IDF가 높은 순으로 정렬합니다. 
w2.sort(key=lambda x: x[1], reverse=True)   #gen을 구성하는 단어들을 TF-IDF가 높은 순으로 정렬합니다.

#상위 100개의 단어들 중 중복되는 단어를 제외하고 상위 n(=15)개의 단어를 추출
n = 15
w1_, w2_ = [], []
for i in range(100):
    w1_.append(vectorizer.get_feature_names()[w1[i][0]])
    w2_.append(vectorizer.get_feature_names()[w2[i][0]])

print(w1_)
print(w2_)
    
# w1에만 있고 w2에는 없는, 예술영화를 잘 대표하는 단어를 15개 추출한다.
target_art, target_gen = [], []
for i in range(100):
    if (w1_[i] not in w2_) and (w1_[i] in model_all.wv): target_art.append(w1_[i])
    if len(target_art) == n: break 

# w2에만 있고 w1에는 없는, 일반영화를 잘 대표하는 단어를 15개 추출한다.
for i in range(100):
    if (w2_[i] not in w1_) and (w2_[i] in model_all.wv): target_gen.append(w2_[i])
    if len(target_gen) == n: break

print('target_art :', target_art)
print('target_get :', target_gen)
# Out:
# (2, 41082)
# ['그녀', '자신', '시작', '위해', '사랑', '사람', '영화', '친구', '남자', '가족', '이야기', '마을', '사건', '마음', '세상', '아버지', '아이', '엄마', '모든', '여자', '대한', '서로', '과연', '다시', '시간', '아들', '소녀', '아내', '다른', '사이', '영화제', '세계', '사실', '하나', '점점', '남편', '감독', '여행', '인생', '발견', '모두', '순간', '우리', '가장', '마지막', '생활', '아빠', '모습', '통해', '죽음', '기억', '비밀', '학교', '음악', '한편', '소년', '생각', '도시', '명의', '사고', '결혼', '전쟁', '때문', '위기', '이제', '최고', '이자', '과거', '일상', '경찰', '상황', '간다', '미국', '결심', '운명', '현실', '관계', '지금', '단편', '여인', '하루', '이름', '이후', '준비', '인간', '감정', '만난', '국제', '처음', '충격', '살인', '누구', '동안', '존재', '그린', '어머니', '연인', '계속', '동생', '작품']
# ['자신', '그녀', '영화제', '위해', '사람', '시작', '국제', '영화', '친구', '사랑', '남자', '이야기', '대한', '서울', '여자', '사건', '남편', '아이', '가족', '아버지', '다른', '마을', '시간', '엄마', '아들', '모든', '단편', '마음', '사실', '다시', '세계', '모습', '작품', '통해', '생각', '서로', '세상', '발견', '감독', '아내', '관계', '소녀', '사이', '하나', '우리', '애니메이션', '때문', '여성', '죽음', '과연', '점점', '인간', '생활', '한편', '결혼', '상황', '모두', '기억', '명의', '소년', '여행', '가장', '간다', '순간', '이제', '도시', '비밀', '학교', '과거', '가지', '이자', '경찰', '마지막', '미국', '동안', '전쟁', '주인공', '대해', '존재', '현실', '연출', '사고', '살인', '일상', '어머니', '계속', '사회', '인생', '다큐멘터리', '부문', '섹스', '최고', '바로', '동생', '의도', '하루', '위기', '계획', '정체', '한국']
# target_art : ['아빠', '음악', '결심', '운명', '지금', '여인', '이름', '이후', '준비', '감정', '만난', '처음', '충격', '누구', '그린']
# target_get : ['서울', '애니메이션', '여성', '가지', '주인공', '대해', '연출', '사회', '다큐멘터리', '부문', '섹스', '바로', '의도', '계획', '정체']

# %%
# 2). TF-IDF로 해당 데이터를 가장 잘 표현하는 단어 셋 만들기
vectorizer_g = TfidfVectorizer()
X_g = vectorizer_g.fit_transform(genre_all_str)

print(X_g.shape)


m = [X_g[i].tocoo() for i in range(X_g.shape[0])] # TF-IDF로 표현한 sparse matrix list를 가져옵니다

w = [[[i, j] for i, j in zip(mm.col, mm.data)] for mm in m]


for i in range(len(w)):
    w[i].sort(key=lambda x: x[1], reverse=True) #단어들을 TF-IDF가 높은 순으로 정렬합니다.
    
    
attributes = []
for i in range(len(w)):
    print(genre_name[i], end=': ')
    attr = []
    j = 0
    while (len(attr) < 15):
        if vectorizer_g.get_feature_names()[w[i][j][0]] in model_all.wv:
            attr.append(vectorizer_g.get_feature_names()[w[i][j][0]])
        j += 1
    print( attr)
    attributes.append(attr)
    print()

# <-- 장르마다 중복된 단어 있음
# Out:
# (21, 42191)
# SF: ['위해', '자신', '지구', '시작', '사람', '인류', '인간', '미래', '우주', '그녀', '로봇', '세계', '모든', '박사', '우주선']
#
# 가족: ['엄마', '아빠', '가족', '영화제', '자신', '위해', '친구', '아주르', '아버지', '시작', '그녀', '아들', '마을', '국제', '낙타']
#
# 공연: ['오페라', '사랑', '토스카', '실황', '올레', '자신', '카바', '그녀', '공연', '오텔로', '리골레토', '백작', '프레', '베르디', '위해']
#
# 공포(호러): ['시작', '위해', '사람', '자신', '친구', '그녀', '사건', '공포', '발견', '죽음', '마을', '가족', '악령', '남자', '좀비']
#
# 기타: ['영화제', '국제', '서울', '단편', '영화', '자신', '사람', '이야기', '그녀', '남자', '위해', '시작', '사랑', '뉴미디어', '페스티벌']
#
# 다큐멘터리: ['영화제', '영화', '다큐', '국제', '다큐멘터리', '사람', '이야기', '대한', '자신', '감독', '위해', '서울', '우리', '시작', '세계']
#
# 드라마: ['자신', '영화제', '그녀', '사람', '사랑', '영화', '위해', '시작', '국제', '남자', '친구', '이야기', '엄마', '여자', '아버지']
#
# 멜로로맨스: ['그녀', '사랑', '자신', '시작', '남편', '남자', '여자', '사람', '친구', '섹스', '위해', '마음', '결혼', '서로', '아내']
#
# 뮤지컬: ['뮤지컬', '사랑', '에스메랄다', '그녀', '음악', '충무로', '모차르트', '영화', '토스카', '자신', '니웨', '카바', '영화제', '바흐', '페뷔스']
#
# 미스터리: ['사건', '그녀', '시작', '자신', '위해', '사람', '발견', '사고', '진실', '죽음', '기억', '살인', '친구', '아내', '남자']
#
# 범죄: ['사건', '위해', '자신', '경찰', '시작', '그녀', '범죄', '조직', '살인', '사람', '마약', '형사', '남자', '모든', '살해']
#
# 사극: ['조선', '위해', '시작', '신기전', '사랑', '자신', '아가멤논', '황제', '그녀', '루안', '최고', '운명', '사람', '하선', '전쟁']
#
# 서부극(웨스턴): ['서부', '보안관', '위해', '벌린', '카우보이', '그레이프바인', '헨리', '마을', '자신', '개릿', '아이', '시작', '무법자', '프린트', '마적']
#
# 성인물(에로): ['그녀', '남편', '마사지', '자신', '섹스', '관계', '영화', '정사', '남자', '위해', '시작', '여자', '유부녀', '마음', '사랑']
#
# 스릴러: ['자신', '그녀', '사건', '시작', '위해', '사람', '살인', '남자', '발견', '아내', '경찰', '친구', '모든', '사실', '살해']
#
# 애니메이션: ['애니메이션', '국제', '영화제', '친구', '인디애니페스트', '위해', '자신', '시작', '사람', '페스티벌', '서울', '이야기', '아이', '마을', '소녀']
#
# 액션: ['위해', '자신', '시작', '조직', '사건', '사람', '그녀', '경찰', '전쟁', '모든', '목숨', '사실', '친구', '가족', '요원']
#
# 어드벤처: ['위해', '자신', '시작', '친구', '마을', '아버지', '영화', '아이', '사람', '여행', '세계', '앤트', '세상', '가족', '모험']
#
# 전쟁: ['전쟁', '독일군', '전투', '위해', '작전', '시작', '부대', '윈터스', '독일', '연합군', '미군', '임무', '자신', '사람', '나치']
#
# 코미디: ['그녀', '자신', '시작', '위해', '사랑', '사람', '친구', '영화', '남자', '여자', '영화제', '가족', '과연', '마을', '사건']
#
# 판타지: ['자신', '그녀', '시작', '위해', '사람', '사랑', '요괴', '영화제', '이야기', '영화', '소녀', '남자', '인간', '세상', '마을']

# %%
# 5. embedding model과 단어 셋으로 WEAT score 구해보기

#target_X 는 art, target_Y 는 gen으로 고정하고 attribute_A, attribute_B를 바꿔가면서 구해봅시다. 
# 구한 결과를 21x21 매트릭스 형태로 표현해서 matrix 라는 변수에 담아봅시다.
matrix = [[0 for _ in range(len(genre_name))] for _ in range(len(genre_name))]


X = np.array([model_all.wv[word] for word in target_art])
Y = np.array([model_all.wv[word] for word in target_gen])

for i in range(len(genre_name)-1):
    for j in range(i+1, len(genre_name)):
        A = np.array([model_all.wv[word] for word in attributes[i]])
        B = np.array([model_all.wv[word] for word in attributes[j]])
        matrix[i][j] = weat_score(X, Y, A, B)

for i in range(len(genre_name)-1):
    for j in range(i+1, len(genre_name)):
        print(genre_name[i], genre_name[j],matrix[i][j])

# %%
def compute_weat_matrix(genre_names, attribute_sets, target_art, target_gen, model, verbose=True):
    """
    장르 쌍 간 WEAT 점수를 계산하는 행렬을 반환합니다.
    
    Args:
        genre_names (List[str]): 장르 이름 리스트
        attribute_sets (Dict[str, List[str]]): 각 장르에 대한 속성 단어 리스트
        target_art (List[str]): 예술영화 대표 단어 리스트
        target_gen (List[str]): 일반영화 대표 단어 리스트
        model (gensim Word2Vec): 학습된 Word2Vec 모델
        weat_score_fn (function): WEAT 점수를 계산하는 함수
        verbose (bool): True일 경우 결과를 출력

    Returns:
        matrix (2D List[float]): 장르 쌍 간 WEAT 점수 행렬 (대각선 위 삼각형만 사용)
    """

    n = len(genre_names)
    matrix = [[0 for _ in range(n)] for _ in range(n)]

    # X, Y는 고정된 target (예술, 일반 영화)
    X = np.array([model.wv[word] for word in target_art if word in model.wv])
    Y = np.array([model.wv[word] for word in target_gen if word in model.wv])

    for i in range(n - 1):
        for j in range(i + 1, n):
            #A_words = [w for w in attribute_sets[genre_names[i]] if w in model.wv]
            #B_words = [w for w in attribute_sets[genre_names[j]] if w in model.wv]

           # if not A_words or not B_words:
           #     matrix[i][j] = None  # 단어가 없으면 계산 불가
           #     continue

           # A = np.array([model.wv[word] for word in A_words])
            #B = np.array([model.wv[word] for word in B_words])
            A = np.array([model_all.wv[word] for word in attributes[i]])
            B = np.array([model_all.wv[word] for word in attributes[j]])
            
            score = weat_score(X, Y, A, B)
            matrix[i][j] = score

            if verbose:
                print(f"예술영화 vs 상업영화 | {genre_names[i]} vs {genre_names[j]}: WEAT score = {score:.4f}")

    return matrix

# %%
matrix_tfidf = compute_weat_matrix(
    genre_names=genre_name,
    #attribute_sets={g: genre_tokens_dict[g]['representative_words'] for g in genre_name},
    attribute_sets=attributes, # TF-IDF로 추출한 단어들
    target_art=target_art,
    target_gen=target_gen,
    model=model_all
)
# Out:
# 예술영화 vs 상업영화 | SF vs 가족: WEAT score = -0.5133
# 예술영화 vs 상업영화 | SF vs 공연: WEAT score = -0.3624
# 예술영화 vs 상업영화 | SF vs 공포(호러): WEAT score = -0.6788
# 예술영화 vs 상업영화 | SF vs 기타: WEAT score = 0.3511
# 예술영화 vs 상업영화 | SF vs 다큐멘터리: WEAT score = 0.5950
# 예술영화 vs 상업영화 | SF vs 드라마: WEAT score = -0.3644
# 예술영화 vs 상업영화 | SF vs 멜로로맨스: WEAT score = -0.7948
# 예술영화 vs 상업영화 | SF vs 뮤지컬: WEAT score = 0.3435
# 예술영화 vs 상업영화 | SF vs 미스터리: WEAT score = -0.6950
# 예술영화 vs 상업영화 | SF vs 범죄: WEAT score = -0.2420
# 예술영화 vs 상업영화 | SF vs 사극: WEAT score = -0.8704
# 예술영화 vs 상업영화 | SF vs 서부극(웨스턴): WEAT score = -0.4199
# 예술영화 vs 상업영화 | SF vs 성인물(에로): WEAT score = -0.5729
# 예술영화 vs 상업영화 | SF vs 스릴러: WEAT score = -0.5297
# 예술영화 vs 상업영화 | SF vs 애니메이션: WEAT score = 0.3895
# 예술영화 vs 상업영화 | SF vs 액션: WEAT score = -0.4859
# 예술영화 vs 상업영화 | SF vs 어드벤처: WEAT score = -0.8109
# 예술영화 vs 상업영화 | SF vs 전쟁: WEAT score = 0.1898
# 예술영화 vs 상업영화 | SF vs 코미디: WEAT score = -0.4537
# 예술영화 vs 상업영화 | SF vs 판타지: WEAT score = -0.1743
# 예술영화 vs 상업영화 | 가족 vs 공연: WEAT score = 0.2231
# 예술영화 vs 상업영화 | 가족 vs 공포(호러): WEAT score = -0.1560
# 예술영화 vs 상업영화 | 가족 vs 기타: WEAT score = 0.7453
# 예술영화 vs 상업영화 | 가족 vs 다큐멘터리: WEAT score = 0.8223
# 예술영화 vs 상업영화 | 가족 vs 드라마: WEAT score = 0.2332
# 예술영화 vs 상업영화 | 가족 vs 멜로로맨스: WEAT score = -0.6343
# 예술영화 vs 상업영화 | 가족 vs 뮤지컬: WEAT score = 0.6975
# 예술영화 vs 상업영화 | 가족 vs 미스터리: WEAT score = -0.3133
# 예술영화 vs 상업영화 | 가족 vs 범죄: WEAT score = 0.2126
# 예술영화 vs 상업영화 | 가족 vs 사극: WEAT score = -0.1011
# 예술영화 vs 상업영화 | 가족 vs 서부극(웨스턴): WEAT score = 0.4525
# 예술영화 vs 상업영화 | 가족 vs 성인물(에로): WEAT score = -0.3212
# 예술영화 vs 상업영화 | 가족 vs 스릴러: WEAT score = -0.1398
# 예술영화 vs 상업영화 | 가족 vs 애니메이션: WEAT score = 0.8722
# 예술영화 vs 상업영화 | 가족 vs 액션: WEAT score = 0.0949
# 예술영화 vs 상업영화 | 가족 vs 어드벤처: WEAT score = -0.0333
# 예술영화 vs 상업영화 | 가족 vs 전쟁: WEAT score = 0.6272
# 예술영화 vs 상업영화 | 가족 vs 코미디: WEAT score = 0.1885
# 예술영화 vs 상업영화 | 가족 vs 판타지: WEAT score = 0.4332
# 예술영화 vs 상업영화 | 공연 vs 공포(호러): WEAT score = -0.2677
# 예술영화 vs 상업영화 | 공연 vs 기타: WEAT score = 0.9070
# 예술영화 vs 상업영화 | 공연 vs 다큐멘터리: WEAT score = 0.9023
# 예술영화 vs 상업영화 | 공연 vs 드라마: WEAT score = -0.0098
# 예술영화 vs 상업영화 | 공연 vs 멜로로맨스: WEAT score = -0.7361
# 예술영화 vs 상업영화 | 공연 vs 뮤지컬: WEAT score = 0.8662
# 예술영화 vs 상업영화 | 공연 vs 미스터리: WEAT score = -0.3854
# 예술영화 vs 상업영화 | 공연 vs 범죄: WEAT score = 0.0616
# 예술영화 vs 상업영화 | 공연 vs 사극: WEAT score = -0.4389
# 예술영화 vs 상업영화 | 공연 vs 서부극(웨스턴): WEAT score = 0.0399
# 예술영화 vs 상업영화 | 공연 vs 성인물(에로): WEAT score = -0.5084
# 예술영화 vs 상업영화 | 공연 vs 스릴러: WEAT score = -0.2413
# 예술영화 vs 상업영화 | 공연 vs 애니메이션: WEAT score = 0.9105
# 예술영화 vs 상업영화 | 공연 vs 액션: WEAT score = -0.0661
# 예술영화 vs 상업영화 | 공연 vs 어드벤처: WEAT score = -0.2511
# 예술영화 vs 상업영화 | 공연 vs 전쟁: WEAT score = 0.5644
# 예술영화 vs 상업영화 | 공연 vs 코미디: WEAT score = -0.0466
# 예술영화 vs 상업영화 | 공연 vs 판타지: WEAT score = 0.3137
# 예술영화 vs 상업영화 | 공포(호러) vs 기타: WEAT score = 0.6486
# 예술영화 vs 상업영화 | 공포(호러) vs 다큐멘터리: WEAT score = 0.7488
# 예술영화 vs 상업영화 | 공포(호러) vs 드라마: WEAT score = 0.3203
# 예술영화 vs 상업영화 | 공포(호러) vs 멜로로맨스: WEAT score = -0.6425
# 예술영화 vs 상업영화 | 공포(호러) vs 뮤지컬: WEAT score = 0.6225
# 예술영화 vs 상업영화 | 공포(호러) vs 미스터리: WEAT score = -0.6024
# 예술영화 vs 상업영화 | 공포(호러) vs 범죄: WEAT score = 0.6691
# 예술영화 vs 상업영화 | 공포(호러) vs 사극: WEAT score = 0.0871
# 예술영화 vs 상업영화 | 공포(호러) vs 서부극(웨스턴): WEAT score = 0.4432
# 예술영화 vs 상업영화 | 공포(호러) vs 성인물(에로): WEAT score = -0.2334
# 예술영화 vs 상업영화 | 공포(호러) vs 스릴러: WEAT score = -0.0275
# 예술영화 vs 상업영화 | 공포(호러) vs 애니메이션: WEAT score = 0.6845
# 예술영화 vs 상업영화 | 공포(호러) vs 액션: WEAT score = 0.5087
# 예술영화 vs 상업영화 | 공포(호러) vs 어드벤처: WEAT score = 0.1665
# 예술영화 vs 상업영화 | 공포(호러) vs 전쟁: WEAT score = 0.6344
# 예술영화 vs 상업영화 | 공포(호러) vs 코미디: WEAT score = 0.4244
# 예술영화 vs 상업영화 | 공포(호러) vs 판타지: WEAT score = 0.5392
# 예술영화 vs 상업영화 | 기타 vs 다큐멘터리: WEAT score = 0.5693
# 예술영화 vs 상업영화 | 기타 vs 드라마: WEAT score = -0.8966
# 예술영화 vs 상업영화 | 기타 vs 멜로로맨스: WEAT score = -0.9095
# 예술영화 vs 상업영화 | 기타 vs 뮤지컬: WEAT score = -0.0479
# 예술영화 vs 상업영화 | 기타 vs 미스터리: WEAT score = -0.6788
# 예술영화 vs 상업영화 | 기타 vs 범죄: WEAT score = -0.3957
# 예술영화 vs 상업영화 | 기타 vs 사극: WEAT score = -0.8407
# 예술영화 vs 상업영화 | 기타 vs 서부극(웨스턴): WEAT score = -0.6080
# 예술영화 vs 상업영화 | 기타 vs 성인물(에로): WEAT score = -0.8325
# 예술영화 vs 상업영화 | 기타 vs 스릴러: WEAT score = -0.5751
# 예술영화 vs 상업영화 | 기타 vs 애니메이션: WEAT score = -0.0043
# 예술영화 vs 상업영화 | 기타 vs 액션: WEAT score = -0.4971
# 예술영화 vs 상업영화 | 기타 vs 어드벤처: WEAT score = -0.8137
# 예술영화 vs 상업영화 | 기타 vs 전쟁: WEAT score = -0.2533
# 예술영화 vs 상업영화 | 기타 vs 코미디: WEAT score = -0.7493
# 예술영화 vs 상업영화 | 기타 vs 판타지: WEAT score = -0.6866
# 예술영화 vs 상업영화 | 다큐멘터리 vs 드라마: WEAT score = -0.9119
# 예술영화 vs 상업영화 | 다큐멘터리 vs 멜로로맨스: WEAT score = -0.9064
# 예술영화 vs 상업영화 | 다큐멘터리 vs 뮤지컬: WEAT score = -0.7133
# 예술영화 vs 상업영화 | 다큐멘터리 vs 미스터리: WEAT score = -0.7621
# 예술영화 vs 상업영화 | 다큐멘터리 vs 범죄: WEAT score = -0.5134
# 예술영화 vs 상업영화 | 다큐멘터리 vs 사극: WEAT score = -0.9132
# 예술영화 vs 상업영화 | 다큐멘터리 vs 서부극(웨스턴): WEAT score = -0.7184
# 예술영화 vs 상업영화 | 다큐멘터리 vs 성인물(에로): WEAT score = -0.8392
# 예술영화 vs 상업영화 | 다큐멘터리 vs 스릴러: WEAT score = -0.6598
# 예술영화 vs 상업영화 | 다큐멘터리 vs 애니메이션: WEAT score = -0.5034
# 예술영화 vs 상업영화 | 다큐멘터리 vs 액션: WEAT score = -0.6201
# 예술영화 vs 상업영화 | 다큐멘터리 vs 어드벤처: WEAT score = -0.9541
# 예술영화 vs 상업영화 | 다큐멘터리 vs 전쟁: WEAT score = -0.4609
# 예술영화 vs 상업영화 | 다큐멘터리 vs 코미디: WEAT score = -0.8286
# 예술영화 vs 상업영화 | 다큐멘터리 vs 판타지: WEAT score = -0.8928
# 예술영화 vs 상업영화 | 드라마 vs 멜로로맨스: WEAT score = -0.8617
# 예술영화 vs 상업영화 | 드라마 vs 뮤지컬: WEAT score = 0.8298
# 예술영화 vs 상업영화 | 드라마 vs 미스터리: WEAT score = -0.4475
# 예술영화 vs 상업영화 | 드라마 vs 범죄: WEAT score = 0.0684
# 예술영화 vs 상업영화 | 드라마 vs 사극: WEAT score = -0.3860
# 예술영화 vs 상업영화 | 드라마 vs 서부극(웨스턴): WEAT score = 0.0450
# 예술영화 vs 상업영화 | 드라마 vs 성인물(에로): WEAT score = -0.6084
# 예술영화 vs 상업영화 | 드라마 vs 스릴러: WEAT score = -0.2670
# 예술영화 vs 상업영화 | 드라마 vs 애니메이션: WEAT score = 0.9085
# 예술영화 vs 상업영화 | 드라마 vs 액션: WEAT score = -0.0642
# 예술영화 vs 상업영화 | 드라마 vs 어드벤처: WEAT score = -0.3169
# 예술영화 vs 상업영화 | 드라마 vs 전쟁: WEAT score = 0.4398
# 예술영화 vs 상업영화 | 드라마 vs 코미디: WEAT score = -0.0734
# 예술영화 vs 상업영화 | 드라마 vs 판타지: WEAT score = 0.5205
# 예술영화 vs 상업영화 | 멜로로맨스 vs 뮤지컬: WEAT score = 0.8776
# 예술영화 vs 상업영화 | 멜로로맨스 vs 미스터리: WEAT score = 0.4749
# 예술영화 vs 상업영화 | 멜로로맨스 vs 범죄: WEAT score = 0.8710
# 예술영화 vs 상업영화 | 멜로로맨스 vs 사극: WEAT score = 0.6378
# 예술영화 vs 상업영화 | 멜로로맨스 vs 서부극(웨스턴): WEAT score = 0.7713
# 예술영화 vs 상업영화 | 멜로로맨스 vs 성인물(에로): WEAT score = 0.8299
# 예술영화 vs 상업영화 | 멜로로맨스 vs 스릴러: WEAT score = 0.6769
# 예술영화 vs 상업영화 | 멜로로맨스 vs 애니메이션: WEAT score = 0.8999
# 예술영화 vs 상업영화 | 멜로로맨스 vs 액션: WEAT score = 0.7439
# 예술영화 vs 상업영화 | 멜로로맨스 vs 어드벤처: WEAT score = 0.6055
# 예술영화 vs 상업영화 | 멜로로맨스 vs 전쟁: WEAT score = 0.7954
# 예술영화 vs 상업영화 | 멜로로맨스 vs 코미디: WEAT score = 0.9191
# 예술영화 vs 상업영화 | 멜로로맨스 vs 판타지: WEAT score = 0.8475
# 예술영화 vs 상업영화 | 뮤지컬 vs 미스터리: WEAT score = -0.6574
# 예술영화 vs 상업영화 | 뮤지컬 vs 범죄: WEAT score = -0.3760
# 예술영화 vs 상업영화 | 뮤지컬 vs 사극: WEAT score = -0.8150
# 예술영화 vs 상업영화 | 뮤지컬 vs 서부극(웨스턴): WEAT score = -0.5665
# 예술영화 vs 상업영화 | 뮤지컬 vs 성인물(에로): WEAT score = -0.8032
# 예술영화 vs 상업영화 | 뮤지컬 vs 스릴러: WEAT score = -0.5526
# 예술영화 vs 상업영화 | 뮤지컬 vs 애니메이션: WEAT score = 0.0230
# 예술영화 vs 상업영화 | 뮤지컬 vs 액션: WEAT score = -0.4797
# 예술영화 vs 상업영화 | 뮤지컬 vs 어드벤처: WEAT score = -0.7898
# 예술영화 vs 상업영화 | 뮤지컬 vs 전쟁: WEAT score = -0.2332
# 예술영화 vs 상업영화 | 뮤지컬 vs 코미디: WEAT score = -0.7032
# 예술영화 vs 상업영화 | 뮤지컬 vs 판타지: WEAT score = -0.6607
# 예술영화 vs 상업영화 | 미스터리 vs 범죄: WEAT score = 1.0282
# 예술영화 vs 상업영화 | 미스터리 vs 사극: WEAT score = 0.2808
# 예술영화 vs 상업영화 | 미스터리 vs 서부극(웨스턴): WEAT score = 0.5405
# 예술영화 vs 상업영화 | 미스터리 vs 성인물(에로): WEAT score = -0.0461
# 예술영화 vs 상업영화 | 미스터리 vs 스릴러: WEAT score = 0.7441
# 예술영화 vs 상업영화 | 미스터리 vs 애니메이션: WEAT score = 0.6996
# 예술영화 vs 상업영화 | 미스터리 vs 액션: WEAT score = 0.7569
# 예술영화 vs 상업영화 | 미스터리 vs 어드벤처: WEAT score = 0.3266
# 예술영화 vs 상업영화 | 미스터리 vs 전쟁: WEAT score = 0.6703
# 예술영화 vs 상업영화 | 미스터리 vs 코미디: WEAT score = 0.5548
# 예술영화 vs 상업영화 | 미스터리 vs 판타지: WEAT score = 0.5972
# 예술영화 vs 상업영화 | 범죄 vs 사극: WEAT score = -0.3418
# 예술영화 vs 상업영화 | 범죄 vs 서부극(웨스턴): WEAT score = -0.0577
# 예술영화 vs 상업영화 | 범죄 vs 성인물(에로): WEAT score = -0.5116
# 예술영화 vs 상업영화 | 범죄 vs 스릴러: WEAT score = -0.9902
# 예술영화 vs 상업영화 | 범죄 vs 애니메이션: WEAT score = 0.4093
# 예술영화 vs 상업영화 | 범죄 vs 액션: WEAT score = -0.3915
# 예술영화 vs 상업영화 | 범죄 vs 어드벤처: WEAT score = -0.2342
# 예술영화 vs 상업영화 | 범죄 vs 전쟁: WEAT score = 0.3561
# 예술영화 vs 상업영화 | 범죄 vs 코미디: WEAT score = -0.1136
# 예술영화 vs 상업영화 | 범죄 vs 판타지: WEAT score = 0.1119
# 예술영화 vs 상업영화 | 사극 vs 서부극(웨스턴): WEAT score = 0.4963
# 예술영화 vs 상업영화 | 사극 vs 성인물(에로): WEAT score = -0.3046
# 예술영화 vs 상업영화 | 사극 vs 스릴러: WEAT score = -0.0792
# 예술영화 vs 상업영화 | 사극 vs 애니메이션: WEAT score = 0.8658
# 예술영화 vs 상업영화 | 사극 vs 액션: WEAT score = 0.2251
# 예술영화 vs 상업영화 | 사극 vs 어드벤처: WEAT score = 0.1138
# 예술영화 vs 상업영화 | 사극 vs 전쟁: WEAT score = 0.8908
# 예술영화 vs 상업영화 | 사극 vs 코미디: WEAT score = 0.4707
# 예술영화 vs 상업영화 | 사극 vs 판타지: WEAT score = 0.6911
# 예술영화 vs 상업영화 | 서부극(웨스턴) vs 성인물(에로): WEAT score = -0.4636
# 예술영화 vs 상업영화 | 서부극(웨스턴) vs 스릴러: WEAT score = -0.3605
# 예술영화 vs 상업영화 | 서부극(웨스턴) vs 애니메이션: WEAT score = 0.6977
# 예술영화 vs 상업영화 | 서부극(웨스턴) vs 액션: WEAT score = -0.1466
# 예술영화 vs 상업영화 | 서부극(웨스턴) vs 어드벤처: WEAT score = -0.4182
# 예술영화 vs 상업영화 | 서부극(웨스턴) vs 전쟁: WEAT score = 0.6285
# 예술영화 vs 상업영화 | 서부극(웨스턴) vs 코미디: WEAT score = -0.0944
# 예술영화 vs 상업영화 | 서부극(웨스턴) vs 판타지: WEAT score = 0.2416
# 예술영화 vs 상업영화 | 성인물(에로) vs 스릴러: WEAT score = 0.2263
# 예술영화 vs 상업영화 | 성인물(에로) vs 애니메이션: WEAT score = 0.7890
# 예술영화 vs 상업영화 | 성인물(에로) vs 액션: WEAT score = 0.3821
# 예술영화 vs 상업영화 | 성인물(에로) vs 어드벤처: WEAT score = 0.3067
# 예술영화 vs 상업영화 | 성인물(에로) vs 전쟁: WEAT score = 0.6043
# 예술영화 vs 상업영화 | 성인물(에로) vs 코미디: WEAT score = 0.5990
# 예술영화 vs 상업영화 | 성인물(에로) vs 판타지: WEAT score = 0.6468
# 예술영화 vs 상업영화 | 스릴러 vs 애니메이션: WEAT score = 0.5951
# 예술영화 vs 상업영화 | 스릴러 vs 액션: WEAT score = 0.4866
# 예술영화 vs 상업영화 | 스릴러 vs 어드벤처: WEAT score = 0.1259
# 예술영화 vs 상업영화 | 스릴러 vs 전쟁: WEAT score = 0.5685
# 예술영화 vs 상업영화 | 스릴러 vs 코미디: WEAT score = 0.3180
# 예술영화 vs 상업영화 | 스릴러 vs 판타지: WEAT score = 0.4147
# 예술영화 vs 상업영화 | 애니메이션 vs 액션: WEAT score = -0.5276
# 예술영화 vs 상업영화 | 애니메이션 vs 어드벤처: WEAT score = -0.9206
# 예술영화 vs 상업영화 | 애니메이션 vs 전쟁: WEAT score = -0.2815
# 예술영화 vs 상업영화 | 애니메이션 vs 코미디: WEAT score = -0.7699
# 예술영화 vs 상업영화 | 애니메이션 vs 판타지: WEAT score = -0.7120
# 예술영화 vs 상업영화 | 액션 vs 어드벤처: WEAT score = -0.1267
# 예술영화 vs 상업영화 | 액션 vs 전쟁: WEAT score = 0.5468
# 예술영화 vs 상업영화 | 액션 vs 코미디: WEAT score = 0.0556
# 예술영화 vs 상업영화 | 액션 vs 판타지: WEAT score = 0.2615
# 예술영화 vs 상업영화 | 어드벤처 vs 전쟁: WEAT score = 0.6817
# 예술영화 vs 상업영화 | 어드벤처 vs 코미디: WEAT score = 0.3269
# 예술영화 vs 상업영화 | 어드벤처 vs 판타지: WEAT score = 0.7878
# 예술영화 vs 상업영화 | 전쟁 vs 코미디: WEAT score = -0.4974
# 예술영화 vs 상업영화 | 전쟁 vs 판타지: WEAT score = -0.2502
# 예술영화 vs 상업영화 | 코미디 vs 판타지: WEAT score = 0.5477

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

np.random.seed(0)

# 한글 지원 폰트
sns.set(font='NanumGothic')

# 마이너스 부호 
plt.rcParams['axes.unicode_minus'] = False
plt.figure(figsize=(12, 10))

ax = sns.heatmap(matrix_tfidf, xticklabels=genre_name, yticklabels=genre_name, annot=True,  cmap='RdYlGn_r')
#ax

plt.title('장르 간 WEAT Score (TF-IDF 기반)', fontsize=18)
plt.tight_layout()
plt.show()

plt.savefig('weat_score_heatmap_tfidf.png', dpi=100, bbox_inches='tight')

# %% [markdown]
# ## 3. 중심벡터 유사도 방식으로  단어셋 추출

# %%
target_art_2, target_gen_2 = [], []

# 토큰으로 embedding model 만들기
model_art = Word2Vec(art_tokens, vector_size=100, window=5, min_count=3, sg=0) 
# 중심 벡터
vector_mean = np.mean([model_art.wv[word] for word in model_art.wv.index_to_key], axis=0)

# 중심 벡터에 가장 가까운 단어들
representative_words = model_art.wv.similar_by_vector(vector_mean, topn=20)
target_art_2 = [word for word, _ in representative_words]
print("art 대표 단어:", target_art_2)

# %%
# 대표 단어 추출
target_art_2 = get_representative_words(art_tokens)
target_gen_2 = get_representative_words(gen_tokens)

print("예술영화 대표 단어:", target_art_2)
print("상업영화 대표 단어:", target_gen_2)
# Out:
# 예술영화 대표 단어: ['컥', '샅', '꿋', '떡', '빡', '갬', '흠', '앳', '틈', '쿵', '볕', '잎', '웠', '톰', '뮈']
# 상업영화 대표 단어: ['끙', '넵', '쏙', '킵', '쉿', '짹', '빽', '튠', '츤', '얍', '낄', '끗', '떵', '찹', '쩔']

# %%
attribute_sets = []
attribute_sets = {g: genre_tokens_dict[g]['representative_words'] for g in genre_name}

matrix_meanvt = compute_weat_matrix(
    genre_names=genre_name,
    attribute_sets=attribute_sets, # 중심벡터 유사도로 추출한 단어들
    target_art=target_art_2,
    target_gen=target_gen_2,
    model=model_all
)
# Out:
# 예술영화 vs 상업영화 | SF vs 가족: WEAT score = -0.3026
# 예술영화 vs 상업영화 | SF vs 공연: WEAT score = 0.0086
# 예술영화 vs 상업영화 | SF vs 공포(호러): WEAT score = -1.0345
# 예술영화 vs 상업영화 | SF vs 기타: WEAT score = 0.4869
# 예술영화 vs 상업영화 | SF vs 다큐멘터리: WEAT score = 0.3711
# 예술영화 vs 상업영화 | SF vs 드라마: WEAT score = -0.2966
# 예술영화 vs 상업영화 | SF vs 멜로로맨스: WEAT score = -0.5312
# 예술영화 vs 상업영화 | SF vs 뮤지컬: WEAT score = 0.3015
# 예술영화 vs 상업영화 | SF vs 미스터리: WEAT score = -0.8755
# 예술영화 vs 상업영화 | SF vs 범죄: WEAT score = -0.3944
# 예술영화 vs 상업영화 | SF vs 사극: WEAT score = -0.6703
# 예술영화 vs 상업영화 | SF vs 서부극(웨스턴): WEAT score = -0.7997
# 예술영화 vs 상업영화 | SF vs 성인물(에로): WEAT score = -0.4270
# 예술영화 vs 상업영화 | SF vs 스릴러: WEAT score = -0.7424
# 예술영화 vs 상업영화 | SF vs 애니메이션: WEAT score = 0.4195
# 예술영화 vs 상업영화 | SF vs 액션: WEAT score = -0.6275
# 예술영화 vs 상업영화 | SF vs 어드벤처: WEAT score = -1.0484
# 예술영화 vs 상업영화 | SF vs 전쟁: WEAT score = 0.2521
# 예술영화 vs 상업영화 | SF vs 코미디: WEAT score = -0.7639
# 예술영화 vs 상업영화 | SF vs 판타지: WEAT score = -0.4644
# 예술영화 vs 상업영화 | 가족 vs 공연: WEAT score = 0.6719
# 예술영화 vs 상업영화 | 가족 vs 공포(호러): WEAT score = -0.7887
# 예술영화 vs 상업영화 | 가족 vs 기타: WEAT score = 0.6304
# 예술영화 vs 상업영화 | 가족 vs 다큐멘터리: WEAT score = 0.4358
# 예술영화 vs 상업영화 | 가족 vs 드라마: WEAT score = 0.0966
# 예술영화 vs 상업영화 | 가족 vs 멜로로맨스: WEAT score = -0.5066
# 예술영화 vs 상업영화 | 가족 vs 뮤지컬: WEAT score = 0.4944
# 예술영화 vs 상업영화 | 가족 vs 미스터리: WEAT score = -0.8541
# 예술영화 vs 상업영화 | 가족 vs 범죄: WEAT score = -0.1724
# 예술영화 vs 상업영화 | 가족 vs 사극: WEAT score = -0.1498
# 예술영화 vs 상업영화 | 가족 vs 서부극(웨스턴): WEAT score = -0.5591
# 예술영화 vs 상업영화 | 가족 vs 성인물(에로): WEAT score = -0.3280
# 예술영화 vs 상업영화 | 가족 vs 스릴러: WEAT score = -0.8786
# 예술영화 vs 상업영화 | 가족 vs 애니메이션: WEAT score = 0.6038
# 예술영화 vs 상업영화 | 가족 vs 액션: WEAT score = -0.4838
# 예술영화 vs 상업영화 | 가족 vs 어드벤처: WEAT score = -0.4669
# 예술영화 vs 상업영화 | 가족 vs 전쟁: WEAT score = 0.4816
# 예술영화 vs 상업영화 | 가족 vs 코미디: WEAT score = -0.3101
# 예술영화 vs 상업영화 | 가족 vs 판타지: WEAT score = 0.0140
# 예술영화 vs 상업영화 | 공연 vs 공포(호러): WEAT score = -0.8689
# 예술영화 vs 상업영화 | 공연 vs 기타: WEAT score = 0.4707
# 예술영화 vs 상업영화 | 공연 vs 다큐멘터리: WEAT score = 0.3031
# 예술영화 vs 상업영화 | 공연 vs 드라마: WEAT score = -0.3381
# 예술영화 vs 상업영화 | 공연 vs 멜로로맨스: WEAT score = -0.5831
# 예술영화 vs 상업영화 | 공연 vs 뮤지컬: WEAT score = 0.3374
# 예술영화 vs 상업영화 | 공연 vs 미스터리: WEAT score = -0.8716
# 예술영화 vs 상업영화 | 공연 vs 범죄: WEAT score = -0.5513
# 예술영화 vs 상업영화 | 공연 vs 사극: WEAT score = -0.6612
# 예술영화 vs 상업영화 | 공연 vs 서부극(웨스턴): WEAT score = -1.0748
# 예술영화 vs 상업영화 | 공연 vs 성인물(에로): WEAT score = -0.4635
# 예술영화 vs 상업영화 | 공연 vs 스릴러: WEAT score = -0.8606
# 예술영화 vs 상업영화 | 공연 vs 애니메이션: WEAT score = 0.4137
# 예술영화 vs 상업영화 | 공연 vs 액션: WEAT score = -0.7870
# 예술영화 vs 상업영화 | 공연 vs 어드벤처: WEAT score = -0.7942
# 예술영화 vs 상업영화 | 공연 vs 전쟁: WEAT score = 0.2788
# 예술영화 vs 상업영화 | 공연 vs 코미디: WEAT score = -0.6827
# 예술영화 vs 상업영화 | 공연 vs 판타지: WEAT score = -0.3064
# 예술영화 vs 상업영화 | 공포(호러) vs 기타: WEAT score = 0.9559
# 예술영화 vs 상업영화 | 공포(호러) vs 다큐멘터리: WEAT score = 0.7721
# 예술영화 vs 상업영화 | 공포(호러) vs 드라마: WEAT score = 0.8853
# 예술영화 vs 상업영화 | 공포(호러) vs 멜로로맨스: WEAT score = 0.0776
# 예술영화 vs 상업영화 | 공포(호러) vs 뮤지컬: WEAT score = 0.8151
# 예술영화 vs 상업영화 | 공포(호러) vs 미스터리: WEAT score = -0.1231
# 예술영화 vs 상업영화 | 공포(호러) vs 범죄: WEAT score = 0.5939
# 예술영화 vs 상업영화 | 공포(호러) vs 사극: WEAT score = 0.8213
# 예술영화 vs 상업영화 | 공포(호러) vs 서부극(웨스턴): WEAT score = 0.5350
# 예술영화 vs 상업영화 | 공포(호러) vs 성인물(에로): WEAT score = 0.2085
# 예술영화 vs 상업영화 | 공포(호러) vs 스릴러: WEAT score = 0.2879
# 예술영화 vs 상업영화 | 공포(호러) vs 애니메이션: WEAT score = 0.9468
# 예술영화 vs 상업영화 | 공포(호러) vs 액션: WEAT score = 0.4257
# 예술영화 vs 상업영화 | 공포(호러) vs 어드벤처: WEAT score = 0.3150
# 예술영화 vs 상업영화 | 공포(호러) vs 전쟁: WEAT score = 0.7785
# 예술영화 vs 상업영화 | 공포(호러) vs 코미디: WEAT score = 0.7375
# 예술영화 vs 상업영화 | 공포(호러) vs 판타지: WEAT score = 0.7562
# 예술영화 vs 상업영화 | 기타 vs 다큐멘터리: WEAT score = -0.0649
# 예술영화 vs 상업영화 | 기타 vs 드라마: WEAT score = -0.9266
# 예술영화 vs 상업영화 | 기타 vs 멜로로맨스: WEAT score = -0.7393
# 예술영화 vs 상업영화 | 기타 vs 뮤지컬: WEAT score = -0.3895
# 예술영화 vs 상업영화 | 기타 vs 미스터리: WEAT score = -0.8833
# 예술영화 vs 상업영화 | 기타 vs 범죄: WEAT score = -0.5598
# 예술영화 vs 상업영화 | 기타 vs 사극: WEAT score = -0.7890
# 예술영화 vs 상업영화 | 기타 vs 서부극(웨스턴): WEAT score = -0.9070
# 예술영화 vs 상업영화 | 기타 vs 성인물(에로): WEAT score = -0.7086
# 예술영화 vs 상업영화 | 기타 vs 스릴러: WEAT score = -0.8105
# 예술영화 vs 상업영화 | 기타 vs 애니메이션: WEAT score = -0.5593
# 예술영화 vs 상업영화 | 기타 vs 액션: WEAT score = -0.6896
# 예술영화 vs 상업영화 | 기타 vs 어드벤처: WEAT score = -1.0752
# 예술영화 vs 상업영화 | 기타 vs 전쟁: WEAT score = -0.1481
# 예술영화 vs 상업영화 | 기타 vs 코미디: WEAT score = -1.0506
# 예술영화 vs 상업영화 | 기타 vs 판타지: WEAT score = -1.0309
# 예술영화 vs 상업영화 | 다큐멘터리 vs 드라마: WEAT score = -0.5590
# 예술영화 vs 상업영화 | 다큐멘터리 vs 멜로로맨스: WEAT score = -0.5673
# 예술영화 vs 상업영화 | 다큐멘터리 vs 뮤지컬: WEAT score = -0.2102
# 예술영화 vs 상업영화 | 다큐멘터리 vs 미스터리: WEAT score = -0.7126
# 예술영화 vs 상업영화 | 다큐멘터리 vs 범죄: WEAT score = -0.4373
# 예술영화 vs 상업영화 | 다큐멘터리 vs 사극: WEAT score = -0.6151
# 예술영화 vs 상업영화 | 다큐멘터리 vs 서부극(웨스턴): WEAT score = -0.7057
# 예술영화 vs 상업영화 | 다큐멘터리 vs 성인물(에로): WEAT score = -0.5278
# 예술영화 vs 상업영화 | 다큐멘터리 vs 스릴러: WEAT score = -0.6306
# 예술영화 vs 상업영화 | 다큐멘터리 vs 애니메이션: WEAT score = -0.1152
# 예술영화 vs 상업영화 | 다큐멘터리 vs 액션: WEAT score = -0.5565
# 예술영화 vs 상업영화 | 다큐멘터리 vs 어드벤처: WEAT score = -0.9358
# 예술영화 vs 상업영화 | 다큐멘터리 vs 전쟁: WEAT score = -0.1056
# 예술영화 vs 상업영화 | 다큐멘터리 vs 코미디: WEAT score = -0.7528
# 예술영화 vs 상업영화 | 다큐멘터리 vs 판타지: WEAT score = -0.7587
# 예술영화 vs 상업영화 | 드라마 vs 멜로로맨스: WEAT score = -0.5625
# 예술영화 vs 상업영화 | 드라마 vs 뮤지컬: WEAT score = 0.6281
# 예술영화 vs 상업영화 | 드라마 vs 미스터리: WEAT score = -0.7989
# 예술영화 vs 상업영화 | 드라마 vs 범죄: WEAT score = -0.1552
# 예술영화 vs 상업영화 | 드라마 vs 사극: WEAT score = -0.2466
# 예술영화 vs 상업영화 | 드라마 vs 서부극(웨스턴): WEAT score = -0.5314
# 예술영화 vs 상업영화 | 드라마 vs 성인물(에로): WEAT score = -0.4427
# 예술영화 vs 상업영화 | 드라마 vs 스릴러: WEAT score = -0.6402
# 예술영화 vs 상업영화 | 드라마 vs 애니메이션: WEAT score = 0.8398
# 예술영화 vs 상업영화 | 드라마 vs 액션: WEAT score = -0.3464
# 예술영화 vs 상업영화 | 드라마 vs 어드벤처: WEAT score = -0.7598
# 예술영화 vs 상업영화 | 드라마 vs 전쟁: WEAT score = 0.3504
# 예술영화 vs 상업영화 | 드라마 vs 코미디: WEAT score = -0.9447
# 예술영화 vs 상업영화 | 드라마 vs 판타지: WEAT score = -0.1207
# 예술영화 vs 상업영화 | 멜로로맨스 vs 뮤지컬: WEAT score = 0.5972
# 예술영화 vs 상업영화 | 멜로로맨스 vs 미스터리: WEAT score = -0.1242
# 예술영화 vs 상업영화 | 멜로로맨스 vs 범죄: WEAT score = 0.3114
# 예술영화 vs 상업영화 | 멜로로맨스 vs 사극: WEAT score = 0.3303
# 예술영화 vs 상업영화 | 멜로로맨스 vs 서부극(웨스턴): WEAT score = 0.1954
# 예술영화 vs 상업영화 | 멜로로맨스 vs 성인물(에로): WEAT score = 0.4304
# 예술영화 vs 상업영화 | 멜로로맨스 vs 스릴러: WEAT score = 0.0577
# 예술영화 vs 상업영화 | 멜로로맨스 vs 애니메이션: WEAT score = 0.6886
# 예술영화 vs 상업영화 | 멜로로맨스 vs 액션: WEAT score = 0.1776
# 예술영화 vs 상업영화 | 멜로로맨스 vs 어드벤처: WEAT score = 0.0895
# 예술영화 vs 상업영화 | 멜로로맨스 vs 전쟁: WEAT score = 0.5092
# 예술영화 vs 상업영화 | 멜로로맨스 vs 코미디: WEAT score = 0.2996
# 예술영화 vs 상업영화 | 멜로로맨스 vs 판타지: WEAT score = 0.4070
# 예술영화 vs 상업영화 | 뮤지컬 vs 미스터리: WEAT score = -0.7629
# 예술영화 vs 상업영화 | 뮤지컬 vs 범죄: WEAT score = -0.4684
# 예술영화 vs 상업영화 | 뮤지컬 vs 사극: WEAT score = -0.6804
# 예술영화 vs 상업영화 | 뮤지컬 vs 서부극(웨스턴): WEAT score = -0.8186
# 예술영화 vs 상업영화 | 뮤지컬 vs 성인물(에로): WEAT score = -0.5454
# 예술영화 vs 상업영화 | 뮤지컬 vs 스릴러: WEAT score = -0.6908
# 예술영화 vs 상업영화 | 뮤지컬 vs 애니메이션: WEAT score = 0.0854
# 예술영화 vs 상업영화 | 뮤지컬 vs 액션: WEAT score = -0.6087
# 예술영화 vs 상업영화 | 뮤지컬 vs 어드벤처: WEAT score = -0.9842
# 예술영화 vs 상업영화 | 뮤지컬 vs 전쟁: WEAT score = -0.0408
# 예술영화 vs 상업영화 | 뮤지컬 vs 코미디: WEAT score = -0.8373
# 예술영화 vs 상업영화 | 뮤지컬 vs 판타지: WEAT score = -0.7313
# 예술영화 vs 상업영화 | 미스터리 vs 범죄: WEAT score = 0.6747
# 예술영화 vs 상업영화 | 미스터리 vs 사극: WEAT score = 0.7363
# 예술영화 vs 상업영화 | 미스터리 vs 서부극(웨스턴): WEAT score = 0.5170
# 예술영화 vs 상업영화 | 미스터리 vs 성인물(에로): WEAT score = 0.2458
# 예술영화 vs 상업영화 | 미스터리 vs 스릴러: WEAT score = 0.5692
# 예술영화 vs 상업영화 | 미스터리 vs 애니메이션: WEAT score = 0.8690
# 예술영화 vs 상업영화 | 미스터리 vs 액션: WEAT score = 0.4825
# 예술영화 vs 상업영화 | 미스터리 vs 어드벤처: WEAT score = 0.2804
# 예술영화 vs 상업영화 | 미스터리 vs 전쟁: WEAT score = 0.7622
# 예술영화 vs 상업영화 | 미스터리 vs 코미디: WEAT score = 0.6130
# 예술영화 vs 상업영화 | 미스터리 vs 판타지: WEAT score = 0.6393
# 예술영화 vs 상업영화 | 범죄 vs 사극: WEAT score = 0.0189
# 예술영화 vs 상업영화 | 범죄 vs 서부극(웨스턴): WEAT score = -0.3043
# 예술영화 vs 상업영화 | 범죄 vs 성인물(에로): WEAT score = -0.1783
# 예술영화 vs 상업영화 | 범죄 vs 스릴러: WEAT score = -0.6520
# 예술영화 vs 상업영화 | 범죄 vs 애니메이션: WEAT score = 0.5396
# 예술영화 vs 상업영화 | 범죄 vs 액션: WEAT score = -0.7700
# 예술영화 vs 상업영화 | 범죄 vs 어드벤처: WEAT score = -0.3031
# 예술영화 vs 상업영화 | 범죄 vs 전쟁: WEAT score = 0.7110
# 예술영화 vs 상업영화 | 범죄 vs 코미디: WEAT score = -0.1106
# 예술영화 vs 상업영화 | 범죄 vs 판타지: WEAT score = 0.0934
# 예술영화 vs 상업영화 | 사극 vs 서부극(웨스턴): WEAT score = -0.9840
# 예술영화 vs 상업영화 | 사극 vs 성인물(에로): WEAT score = -0.2038
# 예술영화 vs 상업영화 | 사극 vs 스릴러: WEAT score = -0.5724
# 예술영화 vs 상업영화 | 사극 vs 애니메이션: WEAT score = 0.7905
# 예술영화 vs 상업영화 | 사극 vs 액션: WEAT score = -0.3773
# 예술영화 vs 상업영화 | 사극 vs 어드벤처: WEAT score = -0.7575
# 예술영화 vs 상업영화 | 사극 vs 전쟁: WEAT score = 0.6704
# 예술영화 vs 상업영화 | 사극 vs 코미디: WEAT score = -0.2683
# 예술영화 vs 상업영화 | 사극 vs 판타지: WEAT score = 0.1585
# 예술영화 vs 상업영화 | 서부극(웨스턴) vs 성인물(에로): WEAT score = -0.0720
# 예술영화 vs 상업영화 | 서부극(웨스턴) vs 스릴러: WEAT score = -0.3310
# 예술영화 vs 상업영화 | 서부극(웨스턴) vs 애니메이션: WEAT score = 0.9340
# 예술영화 vs 상업영화 | 서부극(웨스턴) vs 액션: WEAT score = -0.0179
# 예술영화 vs 상업영화 | 서부극(웨스턴) vs 어드벤처: WEAT score = -0.2716
# 예술영화 vs 상업영화 | 서부극(웨스턴) vs 전쟁: WEAT score = 0.8413
# 예술영화 vs 상업영화 | 서부극(웨스턴) vs 코미디: WEAT score = 0.1579
# 예술영화 vs 상업영화 | 서부극(웨스턴) vs 판타지: WEAT score = 0.3956
# 예술영화 vs 상업영화 | 성인물(에로) vs 스릴러: WEAT score = -0.0962
# 예술영화 vs 상업영화 | 성인물(에로) vs 애니메이션: WEAT score = 0.6371
# 예술영화 vs 상업영화 | 성인물(에로) vs 액션: WEAT score = 0.0589
# 예술영화 vs 상업영화 | 성인물(에로) vs 어드벤처: WEAT score = -0.0213
# 예술영화 vs 상업영화 | 성인물(에로) vs 전쟁: WEAT score = 0.4206
# 예술영화 vs 상업영화 | 성인물(에로) vs 코미디: WEAT score = 0.1589
# 예술영화 vs 상업영화 | 성인물(에로) vs 판타지: WEAT score = 0.3078
# 예술영화 vs 상업영화 | 스릴러 vs 애니메이션: WEAT score = 0.7983
# 예술영화 vs 상업영화 | 스릴러 vs 액션: WEAT score = 0.3513
# 예술영화 vs 상업영화 | 스릴러 vs 어드벤처: WEAT score = 0.0832
# 예술영화 vs 상업영화 | 스릴러 vs 전쟁: WEAT score = 0.7364
# 예술영화 vs 상업영화 | 스릴러 vs 코미디: WEAT score = 0.3863
# 예술영화 vs 상업영화 | 스릴러 vs 판타지: WEAT score = 0.4667
# 예술영화 vs 상업영화 | 애니메이션 vs 액션: WEAT score = -0.6885
# 예술영화 vs 상업영화 | 애니메이션 vs 어드벤처: WEAT score = -1.0793
# 예술영화 vs 상업영화 | 애니메이션 vs 전쟁: WEAT score = -0.0700
# 예술영화 vs 상업영화 | 애니메이션 vs 코미디: WEAT score = -1.0303
# 예술영화 vs 상업영화 | 애니메이션 vs 판타지: WEAT score = -0.9306
# 예술영화 vs 상업영화 | 액션 vs 어드벤처: WEAT score = -0.1404
# 예술영화 vs 상업영화 | 액션 vs 전쟁: WEAT score = 0.8938
# 예술영화 vs 상업영화 | 액션 vs 코미디: WEAT score = 0.0975
# 예술영화 vs 상업영화 | 액션 vs 판타지: WEAT score = 0.2639
# 예술영화 vs 상업영화 | 어드벤처 vs 전쟁: WEAT score = 0.7474
# 예술영화 vs 상업영화 | 어드벤처 vs 코미디: WEAT score = 0.5340
# 예술영화 vs 상업영화 | 어드벤처 vs 판타지: WEAT score = 0.8980
# 예술영화 vs 상업영화 | 전쟁 vs 코미디: WEAT score = -0.5776
# 예술영화 vs 상업영화 | 전쟁 vs 판타지: WEAT score = -0.3823
# 예술영화 vs 상업영화 | 코미디 vs 판타지: WEAT score = 0.5941

# %%
np.random.seed(0)

# 한글 지원 폰트
sns.set(font='NanumGothic')

# 마이너스 부호 
plt.rcParams['axes.unicode_minus'] = False
plt.figure(figsize=(12, 10))

ax = sns.heatmap(matrix_meanvt, xticklabels=genre_name, yticklabels=genre_name, annot=True,  cmap='RdYlGn_r')


plt.title('장르 간 WEAT Score (중심벡터 유사도 기반)', fontsize=18)
plt.tight_layout()
plt.show()

plt.savefig('weat_score_heatmap_meanvt.png', dpi=100, bbox_inches='tight')

# %% [markdown]
# ## 4. 잠재 의미 분석(Latent Semantic Analysis, LSA)

# %%
def get_topics(components, feature_names, n=5):
    for idx, topic in enumerate(components):
        print("Topic %d:" % (idx+1), [(feature_names[i], topic[i].round(5)) for i in topic.argsort()[:-n - 1:-1]])

# %%
def get_top_words_from_first_topic(components, feature_names, n=15):
    first_topic = components[0]
    top_indices = first_topic.argsort()[:-n - 1:-1]
    top_words = [(feature_names[i], round(first_topic[i], 5)) for i in top_indices]
    return top_words

# %%
from sklearn.decomposition import TruncatedSVD

# X
# X_g
print('target TF-IDF 행렬의 크기 :',X.shape)


svd_model = TruncatedSVD(n_components=20, algorithm='randomized', n_iter=100, random_state=122)
svd_model.fit(X)
print('target :', len(svd_model.components_)) # LSA에서 VT


terms = vectorizer.get_feature_names() # 단어 집합
top_words_topic1 = get_top_words_from_first_topic(svd_model.components_, terms)

# 결과 출력
print("Top 15 words in Topic 1:")
for word, score in top_words_topic1:
    print(f"{word}: {score}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1083/3714736354.py in <module>
#       3 # X
#       4 # X_g
# ----> 5 print('target TF-IDF 행렬의 크기 :',X.shape)
#       6
#       7
#
# NameError: name 'X' is not defined

# %%
print('attribute TF-IDF 행렬의 크기 :',X_g.shape)
svd_model_g = TruncatedSVD(n_components=20, algorithm='randomized', n_iter=100, random_state=122)
svd_model_g.fit(X_g)
print('target :', len(svd_model_g.components_))
